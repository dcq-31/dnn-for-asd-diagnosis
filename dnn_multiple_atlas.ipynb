# %% [markdown]
# ## Deep neural network for ASD classification using resting-state fMRI
#
# This notebook evaluate a deep neural network for ASD diagnosis using functional time series data from brain regions of interest. The used resting-state fMRI data from the ABIDE dataset were preprocessed by the **Preprocessed Connectome Project (PCP)** using four pipelines, involving 1100 subjects from multiple international sites.
#
# ### Configure the loading data
#
#  The parameters necessary for loading our neuroimaging data are defined. The `pipeline` and `atlas` used for preprocessing and ROIs extraction are specified. Additionally, we list all neuroimaging sites available in the dataset and select those we want to include in the analysis by the parameter `sites`.

# %%
# Preprocessing pipeline
pipeline = 'cpac'  

# List of ROIs brain atlas
atlases = ['rois_cc200', 'rois_aal']

# Phenotypic data
phenotypic = 'all_cases'

# List of all available neuroimaging sites in the dataset
all_sites = [
    'caltech', 'cmu', 'kki', 'leuven_1', 'leuven_2', 'max_mun', 'nyu', 
    'ohsu', 'olin', 'pitt', 'sbl', 'sdsu', 'stanford', 'trinity', 
    'ucla_1', 'ucla_2', 'um_1', 'um_2', 'usm', 'yale'
]

# Sites include in the analysis
sites = all_sites

# Testing site
test_site = 'yale'

# %% [markdown]
# ### Data loading function
#
# Definition of the `load_atlas_data(pipeline, atlas, sites, phenotypic)` function to retrieve subject time series and diagnostic labels from each neuroimaging site in `sites`. This function reads `phenotypic` information from CSV files, then loads the time series data for each subject. Also handle potential issues, such as missing files or NaN values, to ensure data integrity before analysis.

# %%
import os
import csv
import numpy as np


def load_atlas_data(pipeline, atlases, sites, phenotypic):
    """
    Loads time series and diagnostic labels from neuroimaging data files for the specified sites.
    
    Parameters:
        pipeline (str): Preprocessing pipeline used for the data.
        atlas (str): Atlas defining regions of interest.
        sites (list of str): List of site names to load data from.

    Returns:
        atlas_time_series (dict): Contains time series data for each site.
        atlas_labels (dict): Contains diagnostic labels for each site.
    """

    atlas_time_series = []  # Dictionary to store time series data for each site
    atlas_labels = {}  # Dictionary to store labels for each site
    
    
    print("Load labes:")
    for site in sites:
        # Define path for phenotypic data for the current site
        phenotypic_path = f"data/phenotypic/{phenotypic}/{site}/phenotypic.csv"

        try:
            with open(phenotypic_path, 'r') as file:
                reader = csv.DictReader(file)
                site_labels = []  # List to store labels for each subject at the site

                for row in reader:
                    file_id = row['file_id']  # Unique subject identifier
                    dx_group = row['dx_group']  # Diagnostic group (ASD=1, Control=0)

                    # Define path for the time series data file
                    data_file_path = os.path.join(f"data/{pipeline}/{atlases[0]}/{site}", f"{file_id}_{atlases[0]}.1D")

                    # Check if the data file exists
                    if not os.path.exists(data_file_path):
                        print(f"File Not Found Error: Data file not found at path {data_file_path}")
                        continue
                    
                    data = np.loadtxt(data_file_path)

                    # Check for NaN values and add time series to the site list
                    if np.isnan(data).any():
                        print(f"Value Error: NaN value found for subject {file_id}")
                    else:            
                        site_labels.append(1 if dx_group == '1' else 0)  # Assign 1 for ASD, 0 for control

                # Store loaded data for the current site in the dictionaries
                atlas_labels[site] = np.array(site_labels)
                print(f"Loaded labels {len(site_labels)} subjects from site {site}.")
                
        except FileNotFoundError:
            print(f"File Not Found Error: Phenotypic data not found for site {site}")

    for atlas in atlases:
        atlas_data = {}
        print(f"Data for {atlas} Atlas:")
        for site in sites:
            # Define path for phenotypic data for the current site
            phenotypic_path = f"data/phenotypic/{phenotypic}/{site}/phenotypic.csv"

            try:
                with open(phenotypic_path, 'r') as file:
                    reader = csv.DictReader(file)
                    site_time_series = []  # List to store time series for each subject at the site
                
                    for row in reader:
                        file_id = row['file_id']  # Unique subject identifier
                    
                        # Define path for the time series data file
                        data_file_path = os.path.join(f"data/{pipeline}/{atlas}/{site}", f"{file_id}_{atlas}.1D")

                        # Check if the data file exists
                        if not os.path.exists(data_file_path):
                            print(f"File Not Found Error: Data file not found at path {data_file_path}")
                            continue
                        
                        data = np.loadtxt(data_file_path)

                        # Check for NaN values and add time series to the site list
                        if np.isnan(data).any():
                            print(f"Value Error: NaN value found for subject {file_id}")
                        else:
                            site_time_series.append(data)
                    
                    # Store loaded data for the current site in the dictionaries
                    atlas_data[site] = site_time_series
                    print(f"Loaded {len(site_time_series)} subjects from site {site}.")
                    
            except FileNotFoundError:
                print(f"File Not Found Error: Phenotypic data not found for site {site}")
    
        atlas_time_series.append(atlas_data)
    
    return atlas_time_series, atlas_labels

# %% [markdown]
# Load data to be used in the analysis based on specified parameters.

# %%
atlas_time_series, atlas_labels = load_atlas_data(pipeline, atlases, sites, phenotypic)
# Out:
# Load labes:
# Loaded labels 38 subjects from site caltech.
# Loaded labels 27 subjects from site cmu.
# Loaded labels 55 subjects from site kki.
# Loaded labels 29 subjects from site leuven_1.
# Loaded labels 35 subjects from site leuven_2.
# Loaded labels 57 subjects from site max_mun.
# Loaded labels 184 subjects from site nyu.
# Loaded labels 28 subjects from site ohsu.
# Loaded labels 36 subjects from site olin.
# Loaded labels 57 subjects from site pitt.
# Loaded labels 30 subjects from site sbl.
# Loaded labels 36 subjects from site sdsu.
# Loaded labels 40 subjects from site stanford.
# Loaded labels 49 subjects from site trinity.
# Loaded labels 73 subjects from site ucla_1.
# Loaded labels 26 subjects from site ucla_2.
# Loaded labels 108 subjects from site um_1.
# Loaded labels 35 subjects from site um_2.
# Loaded labels 101 subjects from site usm.
# Loaded labels 56 subjects from site yale.
# Data for rois_cc200 Atlas:
# Loaded 38 subjects from site caltech.
# Loaded 27 subjects from site cmu.
# Loaded 55 subjects from site kki.
# Loaded 29 subjects from site leuven_1.
# Loaded 35 subjects from site leuven_2.
# Loaded 57 subjects from site max_mun.
# Loaded 184 subjects from site nyu.
# Loaded 28 subjects from site ohsu.
# Loaded 36 subjects from site olin.
# Loaded 57 subjects from site pitt.
# Loaded 30 subjects from site sbl.
# Loaded 36 subjects from site sdsu.
# Loaded 40 subjects from site stanford.
# Loaded 49 subjects from site trinity.
# Loaded 73 subjects from site ucla_1.
# Loaded 26 subjects from site ucla_2.
# Loaded 108 subjects from site um_1.
# Loaded 35 subjects from site um_2.
# Loaded 101 subjects from site usm.
# Loaded 56 subjects from site yale.
# Data for rois_aal Atlas:
# Loaded 38 subjects from site caltech.
# Loaded 27 subjects from site cmu.
# Loaded 55 subjects from site kki.
# Loaded 29 subjects from site leuven_1.
# Loaded 35 subjects from site leuven_2.
# Loaded 57 subjects from site max_mun.
# Loaded 184 subjects from site nyu.
# Loaded 28 subjects from site ohsu.
# Loaded 36 subjects from site olin.
# Loaded 57 subjects from site pitt.
# Loaded 30 subjects from site sbl.
# Loaded 36 subjects from site sdsu.
# Loaded 40 subjects from site stanford.
# Loaded 49 subjects from site trinity.
# Loaded 73 subjects from site ucla_1.
# Loaded 26 subjects from site ucla_2.
# Loaded 108 subjects from site um_1.
# Loaded 35 subjects from site um_2.
# Loaded 101 subjects from site usm.
# Loaded 56 subjects from site yale.

# %% [markdown]
# ### Tangent space embedding
#
# This method allows the translation of connectivity matrices from fMRI data into a form that is compatible with Euclidean machine learning techniques while preserving the important geometric properties of the data. This technique is particularly useful when analyzing covariance or correlation matrices in tasks involving brain connectivity and classification of neurological conditions.
#
# The workflow used for this notebooks involves two main steps:
#
# **Estimate the reference tangent space**: Calculate the tangent space projection based on the mean covariance matrix of a training population. This establishes the "reference space" against which individual test subjects can later be projected.
#
# **Project subjects onto the reference space**: Using the precomputed reference tangent space from the population, can be project the covariance matrix of a new subjects onto this space. This will yield a tangent space connectivity matrix for the subjects that aligns with those of the population.
#
# #### Create training population function
#
# Definition of the `create_population(time_series_data)` function for combine the time series into array. To maintain a separate testing set, we exclude the `test_site` site data from the main population data used for estimate the reference tangent space.

# %%
def create_population(time_series_data):
    # Initialize an empty list for the population data 
    population_data = []

    # Loop through the time series data
    for item in time_series_data:
        # Extend each item
        population_data.extend(item)

    print(f"Total subjects in population data: {len(population_data)}")
    return population_data

# %% [markdown]
# #### Estimate the reference tangent space
#
# Calculate the tangent space based on the mean covariance matrix of a training population dataset. This creates a "reference space" that reflects the average connectivity patterns across the population.

# %% [markdown]
# #### Function to estimating tangent space functional connectivity
#
# Definition of the `estimate_tangent_space(data)` function calculate the tangent space based on the geometric mean covariance matrix of a training population dataset. This creates a "reference space" that reflects the average connectivity patterns across the population.
#
# The tangent space representation of functional connectivity is a powerful tool for analyzing brain connectivity. It allows the comparison of individual functional connectivity matrices in a standardized space, computed relative to a group average matrix.

# %%
from nilearn.connectome import ConnectivityMeasure

def estimate_tangent_space(data):
    """
    Estimate the tangent space functional connectivity.

    Parameters:
    -----------
    data : list or ndarray
        List or array of time series data for the training population, where each entry corresponds 
        to a subject's time series (time points x regions).

    Returns:
    --------
    ConnectivityMeasure
        Fitted ConnectivityMeasure object configured for tangent space transformation.
    """
    # Instantiate ConnectivityMeasure for tangent space, vectorizing and discarding the diagonal
    connectivity_measure = ConnectivityMeasure(kind='tangent', vectorize=True, discard_diagonal=True)

    # Fit the measure on the population data to establish a reference tangent space
    connectivity_measure.fit(data)

    return connectivity_measure

# %% [markdown]
# ### Deep neural network model building function
#
# Definition of the `build_model(input_shape)` function create DNN models with the following architecture:
#
# Input Layer: Takes in the number of features from the input data.
#
# Dense Layer 1: 128 neurons, ReLU activation, with L2 regularization to reduce overfitting.
#
# Dense Layer 2: 64 neurons, ReLU activation, L2 regularization.
#
# Output Layer: A single neuron with sigmoid activation for binary classification.
#
# The model is compiled with the Adam optimizer and binary cross-entropy loss, as we aim to classify subjects into two classes. We also include accuracy as a performance metric to track model performance during training and evaluation.

# %%
from keras import layers, models, regularizers

# Define the deep neural network model architecture
def build_model(input_shape):
    """
    Builds and compiles a deep neural network model for binary classification.

    Parameters:
    - input_shape: int, the shape of the input layer, matching the number of features in the dataset

    Returns:
    - model: compiled Keras Sequential model ready for training
    """
    
    model = models.Sequential()

    # Input layer
    model.add(layers.InputLayer(input_shape=input_shape))
    model.add(layers.Dropout(0.2))

    # Hidden layers
    model.add(layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
    model.add(layers.Dropout(0.4))

    model.add(layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
    model.add(layers.Dropout(0.4))

    # Output layer for binary classification (ASD vs. Healthy)
    model.add(layers.Dense(1, activation='sigmoid'))

    # Compile the model with Adam optimizer and binary cross-entropy loss
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %% [markdown]
# ### Definition of training callbacks
#
# To optimize training, we set up three callbacks:
#
# **EarlyStopping:** Stops training if validation loss doesn't improve for 10 epochs, preventing overfitting and restoring the best weights.
#
# **ReduceLROnPlateau:** Reduces the learning rate by 50% when validation loss plateaus for 5 epochs, ensuring gradual and effective model convergence.
#
# **ModelCheckpoint:** Saves the model with the best validation loss to 'best_model.keras', allowing easy access to the optimal version of the model.

# %%
from keras import callbacks

# Early stopping to prevent overfitting by stopping training when validation loss stops improving
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss',             # Monitor validation loss for early stopping
    patience=10,                    # Stop training if val_loss does not improve for 10 epochs
    restore_best_weights=True       # Restore the model weights from the epoch with the lowest val_loss
)

# Reduce learning rate when the validation loss plateaus
reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss',             # Monitor validation loss for learning rate reduction
    factor=0.5,                     # Reduce learning rate by a factor of 0.5
    patience=5,                     # Trigger after 5 epochs without improvement in val_loss
    min_lr=1e-5                     # Set a floor on the learning rate to avoid overly small values
)

# Save the best model based on validation loss
checkpoint = callbacks.ModelCheckpoint(
    'best_model.keras',             # Filename for the best model
    monitor='val_loss',             # Monitor validation loss for checkpoint saving
    save_best_only=True             # Only save the model when it achieves a new best val_loss
)

# Callbacks list passed to the model
callbacks_list = [early_stopping, reduce_lr, checkpoint]

# %% [markdown]
# ### Adjust class balance function
#
# Definition of the `adjust_class_balance(indices, labels)` function for ensures equal representation of all classes by undersampling the majority class(es). This is particularly important in supervised learning, where imbalanced classes can lead to biased models. The function return shuffled list of indices representing a class-balanced subset of the dataset.

# %%
import numpy as np

def adjust_class_balance(indices, labels):
    """
    Adjusts the balance of classes by undersampling the majority class.

    Parameters:
    ----------
    indices : list or ndarray
        Indices of the dataset.
    labels : list or ndarray
        Class labels corresponding to the indices.

    Returns:
    -------
    balanced_indices : ndarray
        Indices of the balanced dataset.
    """
    # Class labels to consider
    CLASS_LABELS = [0, 1]

    # Separate indices by class
    class_indices = {label: [idx for idx in indices if labels[idx] == label] for label in CLASS_LABELS}

    # Determine the minimum class count
    min_class_count = min(len(indices) for indices in class_indices.values())

    # Adjust class balance by undersampling the majority class
    balanced_indices = []
    for label, class_list in class_indices.items():
        if len(class_list) > min_class_count:
            sampled_indices = np.random.choice(class_list, size=min_class_count, replace=False)
            balanced_indices.extend(sampled_indices)
        else:
            balanced_indices.extend(class_list)

    # Shuffle the indices for randomization
    np.random.shuffle(balanced_indices)
    return np.array(balanced_indices)

# %% [markdown]
# ### Stratified cross-validation setup for model training and validation
#
# Set up stratified 10-fold cross-validation for each site (excluding `test_site`) to evaluate model performance across multiple splits. Here’s an overview of the process:
#
# **Stratified k-folds**: StratifiedKFold let to maintain the balance of classes (ASD vs. NC) across each fold, reducing potential bias.
#
# **Fold processing**: For each site, 10 training and validation folds are generated, and indices are stored in the `train_indices` and `val_indices` dictionaries. To ensure class balance after combining all group folds for training data the majority class in each site is undersampling.
#
# **Class balance checks**: For each fold, the balance of ASD and NC samples is shown to confirm each split maintains similar distributions.

# %%
from sklearn.model_selection import StratifiedKFold

# Number of cross-validation folds
n_folds = 10

# Dictionaries for save the training and validation indices
train_indices = {}
val_indices = {}

# Perform stratified k-fold cross-validation for each site, excluding 'test_site' for testing
for site in sites:
    if site == test_site:
        continue

    features = atlas_time_series[0][site]
    labels = atlas_labels[site]

    # Initialize StratifiedKFold with shuffle to ensure data randomization
    skf = StratifiedKFold(n_splits=n_folds, shuffle=True)
    
    site_train_indices = []
    site_val_indices = []

    # Loop through each fold in the stratified split
    for fold, (train_idx, val_idx) in enumerate(skf.split(features, labels)):
        print(f"Processing fold #{fold} for site `{site}`")
      
        train_idx = adjust_class_balance(train_idx, labels)
        val_idx = adjust_class_balance(val_idx, labels)

        # Append training and validation indices for each fold
        site_train_indices.append(np.array(train_idx))
        site_val_indices.append(np.array(val_idx))
        
        # Print class distribution for training and validation sets for each fold
        print(f"Balance of classes in training -> ASD: {np.count_nonzero(labels[site_train_indices[fold]] == 1)} and TC: {np.count_nonzero(labels[site_train_indices[fold]] == 0)}")
        
        print(f"Balance of classes in validation -> ASD: {np.count_nonzero(labels[site_val_indices[fold]] == 1)} and TC: {np.count_nonzero(labels[site_val_indices[fold]] == 0)}")

    # Store indices for each fold in the dictionaries
    train_indices[site] = site_train_indices
    val_indices[site] = site_val_indices
# Out:
# Processing fold #0 for site `caltech`
# Balance of classes in training -> ASD: 17 and TC: 17
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #1 for site `caltech`
# Balance of classes in training -> ASD: 17 and TC: 17
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #2 for site `caltech`
# Balance of classes in training -> ASD: 17 and TC: 17
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #3 for site `caltech`
# Balance of classes in training -> ASD: 17 and TC: 17
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #4 for site `caltech`
# Balance of classes in training -> ASD: 17 and TC: 17
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #5 for site `caltech`
# Balance of classes in training -> ASD: 17 and TC: 17
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #6 for site `caltech`
# Balance of classes in training -> ASD: 17 and TC: 17
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #7 for site `caltech`
# Balance of classes in training -> ASD: 17 and TC: 17
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #8 for site `caltech`
# Balance of classes in training -> ASD: 17 and TC: 17
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #9 for site `caltech`
# Balance of classes in training -> ASD: 17 and TC: 17
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #0 for site `cmu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #1 for site `cmu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #2 for site `cmu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #3 for site `cmu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #4 for site `cmu`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #5 for site `cmu`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #6 for site `cmu`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #7 for site `cmu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #8 for site `cmu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #9 for site `cmu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #0 for site `kki`
# Balance of classes in training -> ASD: 20 and TC: 20
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #1 for site `kki`
# Balance of classes in training -> ASD: 20 and TC: 20
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #2 for site `kki`
# Balance of classes in training -> ASD: 20 and TC: 20
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #3 for site `kki`
# Balance of classes in training -> ASD: 19 and TC: 19
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #4 for site `kki`
# Balance of classes in training -> ASD: 19 and TC: 19
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #5 for site `kki`
# Balance of classes in training -> ASD: 20 and TC: 20
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #6 for site `kki`
# Balance of classes in training -> ASD: 20 and TC: 20
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #7 for site `kki`
# Balance of classes in training -> ASD: 20 and TC: 20
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #8 for site `kki`
# Balance of classes in training -> ASD: 20 and TC: 20
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #9 for site `kki`
# Balance of classes in training -> ASD: 20 and TC: 20
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #0 for site `leuven_1`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #1 for site `leuven_1`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #2 for site `leuven_1`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #3 for site `leuven_1`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #4 for site `leuven_1`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #5 for site `leuven_1`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #6 for site `leuven_1`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #7 for site `leuven_1`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #8 for site `leuven_1`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #9 for site `leuven_1`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #0 for site `leuven_2`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #1 for site `leuven_2`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #2 for site `leuven_2`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #3 for site `leuven_2`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #4 for site `leuven_2`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #5 for site `leuven_2`
# Balance of classes in training -> ASD: 14 and TC: 14
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #6 for site `leuven_2`
# Balance of classes in training -> ASD: 14 and TC: 14
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #7 for site `leuven_2`
# Balance of classes in training -> ASD: 14 and TC: 14
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #8 for site `leuven_2`
# Balance of classes in training -> ASD: 14 and TC: 14
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #9 for site `leuven_2`
# Balance of classes in training -> ASD: 14 and TC: 14
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #0 for site `max_mun`
# Balance of classes in training -> ASD: 21 and TC: 21
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #1 for site `max_mun`
# Balance of classes in training -> ASD: 21 and TC: 21
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #2 for site `max_mun`
# Balance of classes in training -> ASD: 21 and TC: 21
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #3 for site `max_mun`
# Balance of classes in training -> ASD: 21 and TC: 21
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #4 for site `max_mun`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #5 for site `max_mun`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #6 for site `max_mun`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #7 for site `max_mun`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #8 for site `max_mun`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #9 for site `max_mun`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #0 for site `nyu`
# Balance of classes in training -> ASD: 71 and TC: 71
# Balance of classes in validation -> ASD: 8 and TC: 8
# Processing fold #1 for site `nyu`
# Balance of classes in training -> ASD: 71 and TC: 71
# Balance of classes in validation -> ASD: 8 and TC: 8
# Processing fold #2 for site `nyu`
# Balance of classes in training -> ASD: 71 and TC: 71
# Balance of classes in validation -> ASD: 8 and TC: 8
# Processing fold #3 for site `nyu`
# Balance of classes in training -> ASD: 71 and TC: 71
# Balance of classes in validation -> ASD: 8 and TC: 8
# Processing fold #4 for site `nyu`
# Balance of classes in training -> ASD: 71 and TC: 71
# Balance of classes in validation -> ASD: 8 and TC: 8
# Processing fold #5 for site `nyu`
# Balance of classes in training -> ASD: 71 and TC: 71
# Balance of classes in validation -> ASD: 8 and TC: 8
# Processing fold #6 for site `nyu`
# Balance of classes in training -> ASD: 71 and TC: 71
# Balance of classes in validation -> ASD: 8 and TC: 8
# Processing fold #7 for site `nyu`
# Balance of classes in training -> ASD: 71 and TC: 71
# Balance of classes in validation -> ASD: 8 and TC: 8
# Processing fold #8 for site `nyu`
# Balance of classes in training -> ASD: 71 and TC: 71
# Balance of classes in validation -> ASD: 8 and TC: 8
# Processing fold #9 for site `nyu`
# Balance of classes in training -> ASD: 72 and TC: 72
# Balance of classes in validation -> ASD: 7 and TC: 7
# Processing fold #0 for site `ohsu`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #1 for site `ohsu`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #2 for site `ohsu`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #3 for site `ohsu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #4 for site `ohsu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #5 for site `ohsu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #6 for site `ohsu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #7 for site `ohsu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #8 for site `ohsu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #9 for site `ohsu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #0 for site `olin`
# Balance of classes in training -> ASD: 14 and TC: 14
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #1 for site `olin`
# Balance of classes in training -> ASD: 14 and TC: 14
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #2 for site `olin`
# Balance of classes in training -> ASD: 14 and TC: 14
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #3 for site `olin`
# Balance of classes in training -> ASD: 14 and TC: 14
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #4 for site `olin`
# Balance of classes in training -> ASD: 14 and TC: 14
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #5 for site `olin`
# Balance of classes in training -> ASD: 14 and TC: 14
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #6 for site `olin`
# Balance of classes in training -> ASD: 15 and TC: 15
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #7 for site `olin`
# Balance of classes in training -> ASD: 15 and TC: 15
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #8 for site `olin`
# Balance of classes in training -> ASD: 15 and TC: 15
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #9 for site `olin`
# Balance of classes in training -> ASD: 15 and TC: 15
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #0 for site `pitt`
# Balance of classes in training -> ASD: 24 and TC: 24
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #1 for site `pitt`
# Balance of classes in training -> ASD: 24 and TC: 24
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #2 for site `pitt`
# Balance of classes in training -> ASD: 24 and TC: 24
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #3 for site `pitt`
# Balance of classes in training -> ASD: 24 and TC: 24
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #4 for site `pitt`
# Balance of classes in training -> ASD: 24 and TC: 24
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #5 for site `pitt`
# Balance of classes in training -> ASD: 24 and TC: 24
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #6 for site `pitt`
# Balance of classes in training -> ASD: 24 and TC: 24
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #7 for site `pitt`
# Balance of classes in training -> ASD: 25 and TC: 25
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #8 for site `pitt`
# Balance of classes in training -> ASD: 25 and TC: 25
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #9 for site `pitt`
# Balance of classes in training -> ASD: 25 and TC: 25
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #0 for site `sbl`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #1 for site `sbl`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #2 for site `sbl`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #3 for site `sbl`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #4 for site `sbl`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #5 for site `sbl`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #6 for site `sbl`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #7 for site `sbl`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #8 for site `sbl`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #9 for site `sbl`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #0 for site `sdsu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #1 for site `sdsu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #2 for site `sdsu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #3 for site `sdsu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #4 for site `sdsu`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #5 for site `sdsu`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #6 for site `sdsu`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #7 for site `sdsu`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #8 for site `sdsu`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #9 for site `sdsu`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #0 for site `stanford`
# Balance of classes in training -> ASD: 18 and TC: 18
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #1 for site `stanford`
# Balance of classes in training -> ASD: 18 and TC: 18
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #2 for site `stanford`
# Balance of classes in training -> ASD: 18 and TC: 18
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #3 for site `stanford`
# Balance of classes in training -> ASD: 18 and TC: 18
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #4 for site `stanford`
# Balance of classes in training -> ASD: 18 and TC: 18
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #5 for site `stanford`
# Balance of classes in training -> ASD: 18 and TC: 18
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #6 for site `stanford`
# Balance of classes in training -> ASD: 18 and TC: 18
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #7 for site `stanford`
# Balance of classes in training -> ASD: 18 and TC: 18
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #8 for site `stanford`
# Balance of classes in training -> ASD: 18 and TC: 18
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #9 for site `stanford`
# Balance of classes in training -> ASD: 18 and TC: 18
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #0 for site `trinity`
# Balance of classes in training -> ASD: 21 and TC: 21
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #1 for site `trinity`
# Balance of classes in training -> ASD: 21 and TC: 21
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #2 for site `trinity`
# Balance of classes in training -> ASD: 21 and TC: 21
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #3 for site `trinity`
# Balance of classes in training -> ASD: 21 and TC: 21
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #4 for site `trinity`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #5 for site `trinity`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #6 for site `trinity`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #7 for site `trinity`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #8 for site `trinity`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #9 for site `trinity`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #0 for site `ucla_1`
# Balance of classes in training -> ASD: 29 and TC: 29
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #1 for site `ucla_1`
# Balance of classes in training -> ASD: 28 and TC: 28
# Balance of classes in validation -> ASD: 4 and TC: 4
# Processing fold #2 for site `ucla_1`
# Balance of classes in training -> ASD: 28 and TC: 28
# Balance of classes in validation -> ASD: 4 and TC: 4
# Processing fold #3 for site `ucla_1`
# Balance of classes in training -> ASD: 29 and TC: 29
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #4 for site `ucla_1`
# Balance of classes in training -> ASD: 29 and TC: 29
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #5 for site `ucla_1`
# Balance of classes in training -> ASD: 29 and TC: 29
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #6 for site `ucla_1`
# Balance of classes in training -> ASD: 29 and TC: 29
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #7 for site `ucla_1`
# Balance of classes in training -> ASD: 29 and TC: 29
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #8 for site `ucla_1`
# Balance of classes in training -> ASD: 29 and TC: 29
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #9 for site `ucla_1`
# Balance of classes in training -> ASD: 29 and TC: 29
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #0 for site `ucla_2`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #1 for site `ucla_2`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #2 for site `ucla_2`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #3 for site `ucla_2`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #4 for site `ucla_2`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #5 for site `ucla_2`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #6 for site `ucla_2`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #7 for site `ucla_2`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #8 for site `ucla_2`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #9 for site `ucla_2`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #0 for site `um_1`
# Balance of classes in training -> ASD: 47 and TC: 47
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #1 for site `um_1`
# Balance of classes in training -> ASD: 47 and TC: 47
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #2 for site `um_1`
# Balance of classes in training -> ASD: 47 and TC: 47
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #3 for site `um_1`
# Balance of classes in training -> ASD: 48 and TC: 48
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #4 for site `um_1`
# Balance of classes in training -> ASD: 48 and TC: 48
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #5 for site `um_1`
# Balance of classes in training -> ASD: 48 and TC: 48
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #6 for site `um_1`
# Balance of classes in training -> ASD: 48 and TC: 48
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #7 for site `um_1`
# Balance of classes in training -> ASD: 48 and TC: 48
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #8 for site `um_1`
# Balance of classes in training -> ASD: 48 and TC: 48
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #9 for site `um_1`
# Balance of classes in training -> ASD: 48 and TC: 48
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #0 for site `um_2`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #1 for site `um_2`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #2 for site `um_2`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #3 for site `um_2`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #4 for site `um_2`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #5 for site `um_2`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #6 for site `um_2`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #7 for site `um_2`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #8 for site `um_2`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #9 for site `um_2`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #0 for site `usm`
# Balance of classes in training -> ASD: 38 and TC: 38
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #1 for site `usm`
# Balance of classes in training -> ASD: 38 and TC: 38
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #2 for site `usm`
# Balance of classes in training -> ASD: 38 and TC: 38
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #3 for site `usm`
# Balance of classes in training -> ASD: 39 and TC: 39
# Balance of classes in validation -> ASD: 4 and TC: 4
# Processing fold #4 for site `usm`
# Balance of classes in training -> ASD: 39 and TC: 39
# Balance of classes in validation -> ASD: 4 and TC: 4
# Processing fold #5 for site `usm`
# Balance of classes in training -> ASD: 39 and TC: 39
# Balance of classes in validation -> ASD: 4 and TC: 4
# Processing fold #6 for site `usm`
# Balance of classes in training -> ASD: 39 and TC: 39
# Balance of classes in validation -> ASD: 4 and TC: 4
# Processing fold #7 for site `usm`
# Balance of classes in training -> ASD: 39 and TC: 39
# Balance of classes in validation -> ASD: 4 and TC: 4
# Processing fold #8 for site `usm`
# Balance of classes in training -> ASD: 39 and TC: 39
# Balance of classes in validation -> ASD: 4 and TC: 4
# Processing fold #9 for site `usm`
# Balance of classes in training -> ASD: 39 and TC: 39
# Balance of classes in validation -> ASD: 4 and TC: 4

# %% [markdown]
# ###  Evaluation metrics function
#
# Definition of the `calculate_metrics(y_true, y_pred, y_pred_prob)` function to evaluate the performance of a binary classification model. The function computes several key metrics using true labels (y_true), predicted labels (y_pred), and predicted probabilities (y_pred_prob). These metrics include:
#
# **Accuracy**: The proportion of correct predictions among all predictions.
#
# **Sensitivity (Recall)**: The ability to correctly identify positive cases.
#
# **Precision**: The proportion of true positive predictions among all positive predictions.
# **Specificity**: The ability to correctly identify negative cases.
#
# **Area Under the Curve (AUC)**: Measures the ability of the model to distinguish between classes.
# **Confusion Matrix**: Summarizes true/false positives and negatives.
#
# The function handles edge cases where division by zero might occur, ensuring stability in metric computation. This is essential for evaluating the performance of deep learning models in ASD classification tasks.

# %%
from sklearn.metrics import confusion_matrix, roc_auc_score

def calculate_metrics(y_true, y_pred, y_pred_prob):
    """
    Calculate key evaluation metrics for binary classification tasks.

    Parameters:
    -----------
    y_true : array-like
        Ground truth (true labels).
    y_pred : array-like
        Predicted labels (binary).
    y_pred_prob : array-like
        Predicted probabilities for the positive class.

    Returns:
    --------
    accuracy : float
        Proportion of correctly predicted instances.
    sensitivity : float
        True positive rate (recall for the positive class).
    precision : float
        Precision for the positive class.
    specificity : float
        True negative rate (recall for the negative class).
    auc : float
        Area Under the Receiver Operating Characteristic Curve (ROC AUC).
    cm : ndarray
        Confusion matrix as a NumPy array.
    """
    # Compute confusion matrix and unpack values
    cm = confusion_matrix(y_true, y_pred)
    tn, fp, fn, tp = cm.ravel()
    
    # Calculate metrics with safeguards against division by zero
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0.0
    auc = roc_auc_score(y_true, y_pred_prob)
    
    return accuracy, sensitivity, precision, specificity, auc, cm

# %% [markdown]
# ### Function to print metrics
# Definition of the `print_metrics(split, dataset_type, accuracy, sensitivity, precision, specificity, auc, cm)` function, which displays key evaluation metrics for a specific dataset split and type. The function is designed to enhance interpretability during model evaluation by printing the following metrics in a well-formatted manner:
#
# **Accuracy**: The overall correctness of predictions.
#
# **Sensitivity (Recall)**: The ability to correctly detect positive cases.
#
# **Precision**: The reliability of positive predictions.
#
# **Specificity**: The ability to correctly detect negative cases.
#
# **AUC-ROC Score**: The model’s ability to distinguish between positive and negative classes.
#
# **Confusion Matrix**: A tabular summary of prediction outcomes (true positives, false positives, etc.).
#
# The parameters allow for flexible use across various dataset types (e.g., training, validation, test) and splits during cross-validation. For example, split helps track metrics for a specific fold in k-fold cross-validation, while dataset_type differentiates between datasets. The metrics are displayed as percentages for better readability.

# %%
def print_metrics(split, dataset_type, accuracy, sensitivity, precision, specificity, auc, cm):
    """
    Display evaluation metrics for a specific data split and dataset type.

    Parameters:
    -----------
    split : int
        The current split index (zero-based).
    dataset_type : str
        The type of dataset (e.g., "training", "validation", "test").
    accuracy : float
        Proportion of correctly predicted instances.
    sensitivity : float
        True positive rate (recall for the positive class).
    precision : float
        Precision for the positive class.
    specificity : float
        True negative rate (recall for the negative class).
    auc : float
        Area Under the Receiver Operating Characteristic Curve (ROC AUC).
    cm : ndarray
        Confusion matrix as a NumPy array.

    Returns:
    --------
    None
    """
    print(f"\n{dataset_type.capitalize()} Metrics for Split {split + 1}:")
    print(f"  Accuracy: {accuracy * 100:.2f}%")
    print(f"  Sensitivity (Recall): {sensitivity * 100:.2f}%")
    print(f"  Precision: {precision * 100:.2f}%")
    print(f"  Specificity: {specificity * 100:.2f}%")
    print(f"  AUC-ROC Score: {auc * 100:.2f}%")
    print(f"  Confusion Matrix:\n{cm}")

# %% [markdown]
# ### Saving tangent spaces
#
# Prepare connectivity matrices in the tangent space representation for each fold of cross-validation.
#
# **Steps**:
#
# **Initialization**: The `connectivity_list` is created to store tangent space representations for each split.
#
# **Cross-validation Loop**:
# Iterates through each fold defined by n_folds.
# Initializes lists to store training and validation time series data (`X_train_time_series`, `X_val_time_series`) and their corresponding labels (`y_train`, `y_val`).
#
# **Site-Specific Aggregation**:
# For each site, the function aggregates data while excluding the predefined `test_site` for external testing.
# Training and validation data are selected based on indices for the current split.
#
# **Tangent Space Representation**:
# The estimate_tangent_space function is applied to the training data to extract the tangent space representation, which is then appended to `connectivity_list`.
# **Output**:
#
# A list of tangent space representations (`connectivity_list`) for training data across all cross-validation folds.

# %%
connectivity_list = []

for atlas in range(len(atlases)):
    connectivities = []
    # Perform cross-validation across all splits
    for split in range(n_folds):
        print(f"\n--- Split {split + 1} ---")

        # Initialize lists for training and validation data
        X_train_time_series, X_val_time_series = [], []
        y_train, y_val = [], []

        # Aggregate data from all sites except the test site
        for site in sites:
            if site == test_site:  # Skip the test site
                continue

            # Add training data for the current split
            X_train_time_series.extend(
                atlas_time_series[atlas][site][idx] for idx in train_indices[site][split]
            )
            y_train.extend(
                atlas_labels[site][idx] for idx in train_indices[site][split]
            )

            # Add validation data for the current split
            X_val_time_series.extend(
                atlas_time_series[atlas][site][idx] for idx in val_indices[site][split]
            )
            y_val.extend(
                atlas_labels[site][idx] for idx in val_indices[site][split]
            )

        # Estimate tangent space representation for training data
        connectivity_m = estimate_tangent_space(X_train_time_series)
        connectivities.append(connectivity_m)
    connectivity_list.append(connectivities)
# Out:
# --- Split 1 ---
#
# --- Split 2 ---
#
# --- Split 3 ---
#
# --- Split 4 ---
#
# --- Split 5 ---
#
# --- Split 6 ---
#
# --- Split 7 ---
#
# --- Split 8 ---
#
# --- Split 9 ---
#
# --- Split 10 ---
#
# --- Split 1 ---
#
# --- Split 2 ---
#
# --- Split 3 ---
#
# --- Split 4 ---
#
# --- Split 5 ---
#
# --- Split 6 ---
#
# --- Split 7 ---
#
# --- Split 8 ---
#
# --- Split 9 ---
#
# --- Split 10 ---

# %% [markdown]
# ### Cross-validation, feature transformation, and model evaluation
#
# This code performs cross-validation to evaluate the performance of a deep neural network (DNN) model on functional connectivity data from multiple brain atlases. Key steps include:
#
# 1. **Data Aggregation**:
#    - Aggregates time-series data and labels across different sites, excluding the test site.
#    - Transforms data using tangent space embeddings.
#
# 2. **Model Training**:
#    - Trains the DNN model using training data for each split.
#    - Validates the model during training using the validation dataset.
#
# 3. **Performance Evaluation**:
#    - Evaluates the model's predictions using accuracy, sensitivity, precision, specificity, and AUC metrics.
#    - Prints performance for both validation and test datasets for each split.
#
# 4. **Results**:
#    - Outputs mean performance metrics across all splits for both validation and test datasets.
#
# **Key Variables**:
# - `metrics`: Stores accumulated metrics for validation and test datasets.
# - `X_train`, `X_val`, `X_test`: Feature matrices for training, validation, and testing.
# - `y_train`, `y_val`, `y_test`: Corresponding labels.
#
# This workflow helps assess model performance and generalization on unseen data.

# %%
# Initialize accumulators for metrics
metrics = {
    "validation": {"accuracy": 0, "sensitivity": 0, "precision": 0, "specificity": 0, "auc": 0},
    "test": {"accuracy": 0, "sensitivity": 0, "precision": 0, "specificity": 0, "auc": 0}
}

# Cross-validation across all splits
for split in range(n_folds):
    print(f"\n--- Split {split + 1} ---")

    # Aggregate training and validation data across all sites
    y_train, y_val = [], []

    print("Labels")

    for site in sites:
        if site == test_site:
            continue

        y_train.extend([atlas_labels[site][idx] for idx in train_indices[site][split]])
        y_val.extend([atlas_labels[site][idx] for idx in val_indices[site][split]])

    y_test = atlas_labels[test_site]

    print(f"Time series data")
    
    X_train, X_val, X_test = np.array([None]), np.array([None]), np.array([None])
    
    for atlas in range(len(atlases)):
        X_train_time_series_atlas, X_val_time_series_atlas = [], [] 
        
        for site in sites:
            if site == test_site:
                continue
         
            X_train_time_series_atlas.extend([atlas_time_series[atlas][site][idx] for idx in train_indices[site][split]])
            X_val_time_series_atlas.extend([atlas_time_series[atlas][site][idx] for idx in val_indices[site][split]])
         
        # Prepare tangent space for feature extraction
        X_train_atlas = connectivity_list[atlas][split].transform(X_train_time_series_atlas)
        X_val_atlas = connectivity_list[atlas][split].transform(X_val_time_series_atlas)
        X_test_atlas = connectivity_list[atlas][split].transform(atlas_time_series[atlas][test_site])
        
        print(f"atlas {atlases[atlas]}: {X_train_atlas.shape}")
        
        if X_train.any() == None:
            X_train = X_train_atlas
        else:
            X_train = np.concatenate((X_train, X_train_atlas),axis=1)
        
        if X_val.any() == None:
            X_val = X_val_atlas
        else:
            X_val = np.concatenate((X_val, X_val_atlas),axis=1)
        
        if X_test.any() == None:
            X_test = X_test_atlas
        else:
            X_test = np.concatenate((X_test, X_test_atlas),axis=1)

    X_train, X_val, X_test = map(np.array, [X_train, X_val, X_test])
    y_train, y_val, y_test = map(np.array, [y_train, y_val, y_test])

    # Print dataset statistics
    print(f"Training set shape: {X_train.shape}, class balance: ASD={np.sum(y_train == 1)}, TC={np.sum(y_train == 0)}")
    print(f"Validation set shape: {X_val.shape}, class balance: ASD={np.sum(y_val == 1)}, TC={np.sum(y_val == 0)}")
    print(f"Test set shape: {X_test.shape}, class balance: ASD={np.sum(y_test == 1)}, TC={np.sum(y_test == 0)}")

    # Build and train the model
    dnn = build_model(X_train.shape[1])
    history = dnn.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=32, epochs=100, callbacks=callbacks_list)

    # Evaluate on validation set
    validation_pred_prob = dnn.predict(X_val).ravel()
    validation_pred = (validation_pred_prob > 0.5).astype(int)
    acc, sens, prec, spec, auc, cm = calculate_metrics(y_val, validation_pred, validation_pred_prob)
    metrics["validation"]["accuracy"] += acc
    metrics["validation"]["sensitivity"] += sens
    metrics["validation"]["precision"] += prec
    metrics["validation"]["specificity"] += spec
    metrics["validation"]["auc"] += auc
    print_metrics(split, "validation", acc, sens, prec, spec, auc, cm)

    # Evaluate on test set
    test_pred_prob = dnn.predict(X_test).ravel()
    test_pred = (test_pred_prob > 0.5).astype(int)
    acc, sens, prec, spec, auc, cm = calculate_metrics(y_test, test_pred, test_pred_prob)
    metrics["test"]["accuracy"] += acc
    metrics["test"]["sensitivity"] += sens
    metrics["test"]["precision"] += prec
    metrics["test"]["specificity"] += spec
    metrics["test"]["auc"] += auc
    print_metrics(split, "test", acc, sens, prec, spec, auc, cm)

# Print mean metrics
for dataset in metrics:
    print(f"\n--- Mean {dataset.capitalize()} Metrics Across All Splits ---")
    for metric, value in metrics[dataset].items():
        print(f"{metric.capitalize()}: {(value / n_folds) * 100:.2f}%")
# Out:
# --- Split 1 ---
# Labels
# Time series data
# atlas rois_cc200: (834, 19900)
# atlas rois_aal: (834, 6670)
# Training set shape: (834, 26570), class balance: ASD=417, TC=417
# Validation set shape: (94, 26570), class balance: ASD=47, TC=47
# Test set shape: (56, 26570), class balance: ASD=28, TC=28
# Epoch 1/100
# 27/27 [==============================] - 2s 39ms/step - loss: 1.0418 - accuracy: 0.5887 - val_loss: 1.0927 - val_accuracy: 0.6596 - lr: 0.0010
# Epoch 2/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.7743 - accuracy: 0.8861 - val_loss: 1.1863 - val_accuracy: 0.6170 - lr: 0.0010
# Epoch 3/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.5873 - accuracy: 0.9808 - val_loss: 1.2418 - val_accuracy: 0.6277 - lr: 0.0010
# Epoch 4/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.5122 - accuracy: 0.9928 - val_loss: 1.2404 - val_accuracy: 0.6596 - lr: 0.0010
# Epoch 5/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.4533 - accuracy: 0.9976 - val_loss: 1.3239 - val_accuracy: 0.6277 - lr: 0.0010
# Epoch 6/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.4090 - accuracy: 0.9976 - val_loss: 1.2867 - val_accuracy: 0.6596 - lr: 0.0010
# Epoch 7/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3671 - accuracy: 0.9988 - val_loss: 1.2754 - val_accuracy: 0.6596 - lr: 5.0000e-04
# Epoch 8/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3459 - accuracy: 0.9988 - val_loss: 1.2844 - val_accuracy: 0.6383 - lr: 5.0000e-04
# Epoch 9/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.3209 - accuracy: 1.0000 - val_loss: 1.2829 - val_accuracy: 0.6170 - lr: 5.0000e-04
# Epoch 10/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2969 - accuracy: 0.9988 - val_loss: 1.2601 - val_accuracy: 0.6170 - lr: 5.0000e-04
# Epoch 11/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2743 - accuracy: 1.0000 - val_loss: 1.2257 - val_accuracy: 0.6170 - lr: 5.0000e-04
# 3/3 [==============================] - 0s 0s/step
#
# Validation Metrics for Split 1:
#   Accuracy: 65.96%
#   Sensitivity (Recall): 57.45%
#   Precision: 69.23%
#   Specificity: 74.47%
#   AUC-ROC Score: 69.17%
#   Confusion Matrix:
# [[35 12]
#  [20 27]]
# 2/2 [==============================] - 0s 5ms/step
#
# Test Metrics for Split 1:
#   Accuracy: 67.86%
#   Sensitivity (Recall): 64.29%
#   Precision: 69.23%
#   Specificity: 71.43%
#   AUC-ROC Score: 80.87%
#   Confusion Matrix:
# [[20  8]
#  [10 18]]
#
# --- Split 2 ---
# Labels
# Time series data
# atlas rois_cc200: (832, 19900)
# atlas rois_aal: (832, 6670)
# Training set shape: (832, 26570), class balance: ASD=416, TC=416
# Validation set shape: (96, 26570), class balance: ASD=48, TC=48
# Test set shape: (56, 26570), class balance: ASD=28, TC=28
# Epoch 1/100
# 26/26 [==============================] - 1s 37ms/step - loss: 1.0360 - accuracy: 0.6130 - val_loss: 1.0299 - val_accuracy: 0.6771 - lr: 0.0010
# Epoch 2/100
# 26/26 [==============================] - 1s 31ms/step - loss: 0.7965 - accuracy: 0.8666 - val_loss: 0.9739 - val_accuracy: 0.7188 - lr: 0.0010
# Epoch 3/100
# 26/26 [==============================] - 1s 29ms/step - loss: 0.5829 - accuracy: 0.9736 - val_loss: 0.9076 - val_accuracy: 0.7604 - lr: 0.0010
# Epoch 4/100
# 26/26 [==============================] - 1s 29ms/step - loss: 0.4749 - accuracy: 0.9964 - val_loss: 0.8970 - val_accuracy: 0.7292 - lr: 0.0010
# Epoch 5/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.4297 - accuracy: 0.9940 - val_loss: 0.8412 - val_accuracy: 0.7396 - lr: 0.0010
# Epoch 6/100
# 26/26 [==============================] - 1s 29ms/step - loss: 0.3632 - accuracy: 0.9988 - val_loss: 0.8018 - val_accuracy: 0.7396 - lr: 0.0010
# Epoch 7/100
# 26/26 [==============================] - 1s 30ms/step - loss: 0.3153 - accuracy: 0.9988 - val_loss: 0.7391 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 8/100
# 26/26 [==============================] - 1s 28ms/step - loss: 0.2723 - accuracy: 0.9988 - val_loss: 0.7458 - val_accuracy: 0.7396 - lr: 0.0010
# Epoch 9/100
# 26/26 [==============================] - 1s 29ms/step - loss: 0.2340 - accuracy: 0.9988 - val_loss: 0.7014 - val_accuracy: 0.7292 - lr: 0.0010
# Epoch 10/100
# 26/26 [==============================] - 1s 30ms/step - loss: 0.2006 - accuracy: 0.9988 - val_loss: 0.6880 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 11/100
# 26/26 [==============================] - 1s 32ms/step - loss: 0.1740 - accuracy: 0.9988 - val_loss: 0.6845 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 12/100
# 26/26 [==============================] - 1s 29ms/step - loss: 0.1527 - accuracy: 1.0000 - val_loss: 0.6504 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 13/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.1368 - accuracy: 0.9988 - val_loss: 0.6854 - val_accuracy: 0.7292 - lr: 0.0010
# Epoch 14/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.1254 - accuracy: 0.9988 - val_loss: 0.6888 - val_accuracy: 0.7292 - lr: 0.0010
# Epoch 15/100
# 26/26 [==============================] - 1s 33ms/step - loss: 0.1125 - accuracy: 1.0000 - val_loss: 0.6384 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 16/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.1174 - accuracy: 0.9988 - val_loss: 0.6576 - val_accuracy: 0.7396 - lr: 0.0010
# Epoch 17/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.1079 - accuracy: 0.9988 - val_loss: 0.6516 - val_accuracy: 0.7292 - lr: 0.0010
# Epoch 18/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.0930 - accuracy: 1.0000 - val_loss: 0.7053 - val_accuracy: 0.7188 - lr: 0.0010
# Epoch 19/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.0898 - accuracy: 1.0000 - val_loss: 0.6887 - val_accuracy: 0.7188 - lr: 0.0010
# Epoch 20/100
# 26/26 [==============================] - 1s 29ms/step - loss: 0.0870 - accuracy: 1.0000 - val_loss: 0.6428 - val_accuracy: 0.7917 - lr: 0.0010
# Epoch 21/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.0837 - accuracy: 1.0000 - val_loss: 0.6642 - val_accuracy: 0.8021 - lr: 5.0000e-04
# Epoch 22/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.0840 - accuracy: 0.9976 - val_loss: 0.6387 - val_accuracy: 0.7812 - lr: 5.0000e-04
# Epoch 23/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.0777 - accuracy: 0.9988 - val_loss: 0.6544 - val_accuracy: 0.7708 - lr: 5.0000e-04
# Epoch 24/100
# 26/26 [==============================] - 1s 30ms/step - loss: 0.0706 - accuracy: 1.0000 - val_loss: 0.6462 - val_accuracy: 0.7812 - lr: 5.0000e-04
# Epoch 25/100
# 26/26 [==============================] - 1s 29ms/step - loss: 0.0663 - accuracy: 1.0000 - val_loss: 0.6348 - val_accuracy: 0.7604 - lr: 5.0000e-04
# Epoch 26/100
# 26/26 [==============================] - 1s 29ms/step - loss: 0.0634 - accuracy: 1.0000 - val_loss: 0.6072 - val_accuracy: 0.7708 - lr: 5.0000e-04
# Epoch 27/100
# 26/26 [==============================] - 1s 29ms/step - loss: 0.0646 - accuracy: 0.9976 - val_loss: 0.6036 - val_accuracy: 0.7917 - lr: 5.0000e-04
# Epoch 28/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.0684 - accuracy: 0.9988 - val_loss: 0.6753 - val_accuracy: 0.7812 - lr: 5.0000e-04
# Epoch 29/100
# 26/26 [==============================] - 1s 29ms/step - loss: 0.0669 - accuracy: 1.0000 - val_loss: 0.6903 - val_accuracy: 0.7604 - lr: 5.0000e-04
# Epoch 30/100
# 26/26 [==============================] - 1s 29ms/step - loss: 0.0679 - accuracy: 1.0000 - val_loss: 0.7060 - val_accuracy: 0.7604 - lr: 5.0000e-04
# Epoch 31/100
# 26/26 [==============================] - 1s 30ms/step - loss: 0.0699 - accuracy: 0.9988 - val_loss: 0.6635 - val_accuracy: 0.8021 - lr: 5.0000e-04
# Epoch 32/100
# 26/26 [==============================] - 1s 26ms/step - loss: 0.0892 - accuracy: 0.9988 - val_loss: 0.6310 - val_accuracy: 0.8125 - lr: 5.0000e-04
# Epoch 33/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.0777 - accuracy: 0.9988 - val_loss: 0.7206 - val_accuracy: 0.8125 - lr: 2.5000e-04
# Epoch 34/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.0747 - accuracy: 1.0000 - val_loss: 0.7667 - val_accuracy: 0.7708 - lr: 2.5000e-04
# Epoch 35/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.0764 - accuracy: 0.9988 - val_loss: 0.7210 - val_accuracy: 0.7812 - lr: 2.5000e-04
# Epoch 36/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.0685 - accuracy: 1.0000 - val_loss: 0.7314 - val_accuracy: 0.7604 - lr: 2.5000e-04
# Epoch 37/100
# 26/26 [==============================] - 1s 30ms/step - loss: 0.0655 - accuracy: 1.0000 - val_loss: 0.6989 - val_accuracy: 0.7708 - lr: 2.5000e-04
# 3/3 [==============================] - 0s 5ms/step
#
# Validation Metrics for Split 2:
#   Accuracy: 79.17%
#   Sensitivity (Recall): 85.42%
#   Precision: 75.93%
#   Specificity: 72.92%
#   AUC-ROC Score: 83.85%
#   Confusion Matrix:
# [[35 13]
#  [ 7 41]]
# 2/2 [==============================] - 0s 1ms/step
#
# Test Metrics for Split 2:
#   Accuracy: 73.21%
#   Sensitivity (Recall): 75.00%
#   Precision: 72.41%
#   Specificity: 71.43%
#   AUC-ROC Score: 81.12%
#   Confusion Matrix:
# [[20  8]
#  [ 7 21]]
#
# --- Split 3 ---
# Labels
# Time series data
# atlas rois_cc200: (830, 19900)
# atlas rois_aal: (830, 6670)
# Training set shape: (830, 26570), class balance: ASD=415, TC=415
# Validation set shape: (98, 26570), class balance: ASD=49, TC=49
# Test set shape: (56, 26570), class balance: ASD=28, TC=28
# Epoch 1/100
# 26/26 [==============================] - 2s 38ms/step - loss: 1.0507 - accuracy: 0.5916 - val_loss: 1.0070 - val_accuracy: 0.7245 - lr: 0.0010
# Epoch 2/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.7921 - accuracy: 0.8855 - val_loss: 0.9848 - val_accuracy: 0.7245 - lr: 0.0010
# Epoch 3/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.5864 - accuracy: 0.9723 - val_loss: 0.9536 - val_accuracy: 0.7245 - lr: 0.0010
# Epoch 4/100
# 26/26 [==============================] - 1s 31ms/step - loss: 0.4830 - accuracy: 0.9964 - val_loss: 0.9332 - val_accuracy: 0.7449 - lr: 0.0010
# Epoch 5/100
# 26/26 [==============================] - 1s 28ms/step - loss: 0.4179 - accuracy: 0.9988 - val_loss: 0.9185 - val_accuracy: 0.7143 - lr: 0.0010
# Epoch 6/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.3598 - accuracy: 1.0000 - val_loss: 0.8994 - val_accuracy: 0.6939 - lr: 0.0010
# Epoch 7/100
# 26/26 [==============================] - 1s 28ms/step - loss: 0.3101 - accuracy: 1.0000 - val_loss: 0.8524 - val_accuracy: 0.7041 - lr: 0.0010
# Epoch 8/100
# 26/26 [==============================] - 1s 31ms/step - loss: 0.2658 - accuracy: 1.0000 - val_loss: 0.8036 - val_accuracy: 0.7245 - lr: 0.0010
# Epoch 9/100
# 26/26 [==============================] - 1s 28ms/step - loss: 0.2275 - accuracy: 1.0000 - val_loss: 0.7730 - val_accuracy: 0.7041 - lr: 0.0010
# Epoch 10/100
# 26/26 [==============================] - 1s 28ms/step - loss: 0.1939 - accuracy: 1.0000 - val_loss: 0.7488 - val_accuracy: 0.7143 - lr: 0.0010
# Epoch 11/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.1670 - accuracy: 1.0000 - val_loss: 0.7337 - val_accuracy: 0.7245 - lr: 0.0010
# Epoch 12/100
# 26/26 [==============================] - 1s 28ms/step - loss: 0.1450 - accuracy: 1.0000 - val_loss: 0.7015 - val_accuracy: 0.7653 - lr: 0.0010
# Epoch 13/100
# 26/26 [==============================] - 1s 29ms/step - loss: 0.1281 - accuracy: 1.0000 - val_loss: 0.6881 - val_accuracy: 0.7245 - lr: 0.0010
# Epoch 14/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.1131 - accuracy: 1.0000 - val_loss: 0.6950 - val_accuracy: 0.7347 - lr: 0.0010
# Epoch 15/100
# 26/26 [==============================] - 1s 28ms/step - loss: 0.1040 - accuracy: 1.0000 - val_loss: 0.7076 - val_accuracy: 0.7245 - lr: 0.0010
# Epoch 16/100
# 26/26 [==============================] - 1s 31ms/step - loss: 0.0973 - accuracy: 1.0000 - val_loss: 0.6866 - val_accuracy: 0.7449 - lr: 0.0010
# Epoch 17/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.0923 - accuracy: 1.0000 - val_loss: 0.7082 - val_accuracy: 0.7245 - lr: 0.0010
# Epoch 18/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.0890 - accuracy: 1.0000 - val_loss: 0.7731 - val_accuracy: 0.7245 - lr: 0.0010
# Epoch 19/100
# 26/26 [==============================] - 1s 28ms/step - loss: 0.0902 - accuracy: 1.0000 - val_loss: 0.7860 - val_accuracy: 0.7449 - lr: 0.0010
# Epoch 20/100
# 26/26 [==============================] - 1s 30ms/step - loss: 0.1204 - accuracy: 0.9964 - val_loss: 0.9320 - val_accuracy: 0.6939 - lr: 0.0010
# Epoch 21/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.3074 - accuracy: 0.9759 - val_loss: 1.8473 - val_accuracy: 0.6429 - lr: 0.0010
# Epoch 22/100
# 26/26 [==============================] - 1s 28ms/step - loss: 0.6160 - accuracy: 0.9663 - val_loss: 1.7933 - val_accuracy: 0.6020 - lr: 5.0000e-04
# Epoch 23/100
# 26/26 [==============================] - 1s 28ms/step - loss: 0.7075 - accuracy: 0.9687 - val_loss: 2.1174 - val_accuracy: 0.6020 - lr: 5.0000e-04
# Epoch 24/100
# 26/26 [==============================] - 1s 28ms/step - loss: 0.6826 - accuracy: 0.9819 - val_loss: 1.9409 - val_accuracy: 0.6327 - lr: 5.0000e-04
# Epoch 25/100
# 26/26 [==============================] - 1s 31ms/step - loss: 0.6543 - accuracy: 0.9940 - val_loss: 1.9372 - val_accuracy: 0.6531 - lr: 5.0000e-04
# Epoch 26/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.6215 - accuracy: 0.9940 - val_loss: 1.8689 - val_accuracy: 0.6531 - lr: 5.0000e-04
# 4/4 [==============================] - 0s 618us/step
#
# Validation Metrics for Split 3:
#   Accuracy: 74.49%
#   Sensitivity (Recall): 63.27%
#   Precision: 81.58%
#   Specificity: 85.71%
#   AUC-ROC Score: 82.59%
#   Confusion Matrix:
# [[42  7]
#  [18 31]]
# 2/2 [==============================] - 0s 513us/step
#
# Test Metrics for Split 3:
#   Accuracy: 76.79%
#   Sensitivity (Recall): 82.14%
#   Precision: 74.19%
#   Specificity: 71.43%
#   AUC-ROC Score: 82.02%
#   Confusion Matrix:
# [[20  8]
#  [ 5 23]]
#
# --- Split 4 ---
# Labels
# Time series data
# atlas rois_cc200: (836, 19900)
# atlas rois_aal: (836, 6670)
# Training set shape: (836, 26570), class balance: ASD=418, TC=418
# Validation set shape: (96, 26570), class balance: ASD=48, TC=48
# Test set shape: (56, 26570), class balance: ASD=28, TC=28
# Epoch 1/100
# 27/27 [==============================] - 2s 36ms/step - loss: 1.0437 - accuracy: 0.5813 - val_loss: 1.0243 - val_accuracy: 0.6875 - lr: 0.0010
# Epoch 2/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.7986 - accuracy: 0.8840 - val_loss: 1.0182 - val_accuracy: 0.7292 - lr: 0.0010
# Epoch 3/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.6070 - accuracy: 0.9677 - val_loss: 0.9979 - val_accuracy: 0.7396 - lr: 0.0010
# Epoch 4/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.5022 - accuracy: 0.9952 - val_loss: 0.9925 - val_accuracy: 0.7292 - lr: 0.0010
# Epoch 5/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.4445 - accuracy: 0.9976 - val_loss: 0.9527 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 6/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.3915 - accuracy: 1.0000 - val_loss: 0.9227 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 7/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3426 - accuracy: 1.0000 - val_loss: 0.9117 - val_accuracy: 0.6979 - lr: 0.0010
# Epoch 8/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3017 - accuracy: 0.9988 - val_loss: 0.8527 - val_accuracy: 0.7188 - lr: 0.0010
# Epoch 9/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2654 - accuracy: 1.0000 - val_loss: 0.8465 - val_accuracy: 0.7188 - lr: 0.0010
# Epoch 10/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2313 - accuracy: 1.0000 - val_loss: 0.8056 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 11/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.2043 - accuracy: 0.9988 - val_loss: 0.7670 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 12/100
# 27/27 [==============================] - 1s 26ms/step - loss: 0.1798 - accuracy: 1.0000 - val_loss: 0.8012 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 13/100
# 27/27 [==============================] - 1s 26ms/step - loss: 0.1583 - accuracy: 1.0000 - val_loss: 0.8193 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 14/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1401 - accuracy: 1.0000 - val_loss: 0.7917 - val_accuracy: 0.7396 - lr: 0.0010
# Epoch 15/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.1237 - accuracy: 1.0000 - val_loss: 0.7352 - val_accuracy: 0.7396 - lr: 0.0010
# Epoch 16/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1120 - accuracy: 1.0000 - val_loss: 0.7256 - val_accuracy: 0.7604 - lr: 0.0010
# Epoch 17/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1079 - accuracy: 1.0000 - val_loss: 0.8255 - val_accuracy: 0.7396 - lr: 0.0010
# Epoch 18/100
# 27/27 [==============================] - 1s 26ms/step - loss: 0.1064 - accuracy: 1.0000 - val_loss: 0.8596 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 19/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1010 - accuracy: 1.0000 - val_loss: 0.8200 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 20/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0963 - accuracy: 1.0000 - val_loss: 0.8887 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 21/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0954 - accuracy: 1.0000 - val_loss: 0.9535 - val_accuracy: 0.6771 - lr: 0.0010
# Epoch 22/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1127 - accuracy: 0.9988 - val_loss: 0.9279 - val_accuracy: 0.6771 - lr: 5.0000e-04
# Epoch 23/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1278 - accuracy: 1.0000 - val_loss: 0.9444 - val_accuracy: 0.6667 - lr: 5.0000e-04
# Epoch 24/100
# 27/27 [==============================] - 1s 26ms/step - loss: 0.1279 - accuracy: 1.0000 - val_loss: 0.9971 - val_accuracy: 0.6771 - lr: 5.0000e-04
# Epoch 25/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.1232 - accuracy: 0.9976 - val_loss: 0.9771 - val_accuracy: 0.6771 - lr: 5.0000e-04
# Epoch 26/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1158 - accuracy: 1.0000 - val_loss: 0.9543 - val_accuracy: 0.6979 - lr: 5.0000e-04
# 3/3 [==============================] - 0s 0s/step
#
# Validation Metrics for Split 4:
#   Accuracy: 76.04%
#   Sensitivity (Recall): 79.17%
#   Precision: 74.51%
#   Specificity: 72.92%
#   AUC-ROC Score: 81.51%
#   Confusion Matrix:
# [[35 13]
#  [10 38]]
# 2/2 [==============================] - 0s 0s/step
#
# Test Metrics for Split 4:
#   Accuracy: 78.57%
#   Sensitivity (Recall): 82.14%
#   Precision: 76.67%
#   Specificity: 75.00%
#   AUC-ROC Score: 84.82%
#   Confusion Matrix:
# [[21  7]
#  [ 5 23]]
#
# --- Split 5 ---
# Labels
# Time series data
# atlas rois_cc200: (840, 19900)
# atlas rois_aal: (840, 6670)
# Training set shape: (840, 26570), class balance: ASD=420, TC=420
# Validation set shape: (92, 26570), class balance: ASD=46, TC=46
# Test set shape: (56, 26570), class balance: ASD=28, TC=28
# Epoch 1/100
# 27/27 [==============================] - 2s 37ms/step - loss: 1.0416 - accuracy: 0.5893 - val_loss: 1.0400 - val_accuracy: 0.6957 - lr: 0.0010
# Epoch 2/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8281 - accuracy: 0.8655 - val_loss: 1.0131 - val_accuracy: 0.7391 - lr: 0.0010
# Epoch 3/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.6194 - accuracy: 0.9595 - val_loss: 1.0241 - val_accuracy: 0.6957 - lr: 0.0010
# Epoch 4/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.5026 - accuracy: 0.9917 - val_loss: 1.0052 - val_accuracy: 0.6957 - lr: 0.0010
# Epoch 5/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.4381 - accuracy: 0.9988 - val_loss: 1.0077 - val_accuracy: 0.6739 - lr: 0.0010
# Epoch 6/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3798 - accuracy: 0.9976 - val_loss: 1.0149 - val_accuracy: 0.6522 - lr: 0.0010
# Epoch 7/100
# 27/27 [==============================] - 1s 26ms/step - loss: 0.3276 - accuracy: 0.9988 - val_loss: 1.0079 - val_accuracy: 0.6957 - lr: 0.0010
# Epoch 8/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2826 - accuracy: 1.0000 - val_loss: 0.9746 - val_accuracy: 0.6957 - lr: 0.0010
# Epoch 9/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2483 - accuracy: 0.9988 - val_loss: 0.9080 - val_accuracy: 0.6848 - lr: 0.0010
# Epoch 10/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2132 - accuracy: 1.0000 - val_loss: 0.9097 - val_accuracy: 0.6957 - lr: 0.0010
# Epoch 11/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1853 - accuracy: 1.0000 - val_loss: 0.9077 - val_accuracy: 0.6739 - lr: 0.0010
# Epoch 12/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.1616 - accuracy: 1.0000 - val_loss: 0.8693 - val_accuracy: 0.6522 - lr: 0.0010
# Epoch 13/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1448 - accuracy: 1.0000 - val_loss: 0.8823 - val_accuracy: 0.6522 - lr: 0.0010
# Epoch 14/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1297 - accuracy: 1.0000 - val_loss: 0.9318 - val_accuracy: 0.6739 - lr: 0.0010
# Epoch 15/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1172 - accuracy: 1.0000 - val_loss: 0.8268 - val_accuracy: 0.6957 - lr: 0.0010
# Epoch 16/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.1130 - accuracy: 1.0000 - val_loss: 0.8154 - val_accuracy: 0.6739 - lr: 0.0010
# Epoch 17/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1093 - accuracy: 1.0000 - val_loss: 0.8085 - val_accuracy: 0.6739 - lr: 0.0010
# Epoch 18/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1029 - accuracy: 1.0000 - val_loss: 0.9090 - val_accuracy: 0.6957 - lr: 0.0010
# Epoch 19/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0958 - accuracy: 1.0000 - val_loss: 0.8721 - val_accuracy: 0.6739 - lr: 0.0010
# Epoch 20/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0935 - accuracy: 1.0000 - val_loss: 0.9096 - val_accuracy: 0.7065 - lr: 0.0010
# Epoch 21/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0899 - accuracy: 1.0000 - val_loss: 0.9119 - val_accuracy: 0.6848 - lr: 0.0010
# Epoch 22/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0908 - accuracy: 1.0000 - val_loss: 0.9280 - val_accuracy: 0.6630 - lr: 0.0010
# Epoch 23/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0936 - accuracy: 0.9988 - val_loss: 0.8654 - val_accuracy: 0.7174 - lr: 5.0000e-04
# Epoch 24/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1029 - accuracy: 0.9988 - val_loss: 0.9636 - val_accuracy: 0.6739 - lr: 5.0000e-04
# Epoch 25/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.1132 - accuracy: 1.0000 - val_loss: 0.9836 - val_accuracy: 0.6957 - lr: 5.0000e-04
# Epoch 26/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1286 - accuracy: 1.0000 - val_loss: 1.0562 - val_accuracy: 0.7283 - lr: 5.0000e-04
# Epoch 27/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1444 - accuracy: 0.9988 - val_loss: 1.2064 - val_accuracy: 0.6848 - lr: 5.0000e-04
# 3/3 [==============================] - 0s 2ms/step
#
# Validation Metrics for Split 5:
#   Accuracy: 67.39%
#   Sensitivity (Recall): 71.74%
#   Precision: 66.00%
#   Specificity: 63.04%
#   AUC-ROC Score: 77.88%
#   Confusion Matrix:
# [[29 17]
#  [13 33]]
# 2/2 [==============================] - 0s 15ms/step
#
# Test Metrics for Split 5:
#   Accuracy: 73.21%
#   Sensitivity (Recall): 85.71%
#   Precision: 68.57%
#   Specificity: 60.71%
#   AUC-ROC Score: 82.40%
#   Confusion Matrix:
# [[17 11]
#  [ 4 24]]
#
# --- Split 6 ---
# Labels
# Time series data
# atlas rois_cc200: (844, 19900)
# atlas rois_aal: (844, 6670)
# Training set shape: (844, 26570), class balance: ASD=422, TC=422
# Validation set shape: (86, 26570), class balance: ASD=43, TC=43
# Test set shape: (56, 26570), class balance: ASD=28, TC=28
# Epoch 1/100
# 27/27 [==============================] - 2s 37ms/step - loss: 1.0528 - accuracy: 0.5912 - val_loss: 1.0143 - val_accuracy: 0.7442 - lr: 0.0010
# Epoch 2/100
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8034 - accuracy: 0.8827 - val_loss: 0.9924 - val_accuracy: 0.7791 - lr: 0.0010
# Epoch 3/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.6053 - accuracy: 0.9704 - val_loss: 0.9510 - val_accuracy: 0.7907 - lr: 0.0010
# Epoch 4/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.4957 - accuracy: 0.9941 - val_loss: 0.9160 - val_accuracy: 0.8140 - lr: 0.0010
# Epoch 5/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.4335 - accuracy: 0.9964 - val_loss: 0.9072 - val_accuracy: 0.8023 - lr: 0.0010
# Epoch 6/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3805 - accuracy: 0.9976 - val_loss: 0.8423 - val_accuracy: 0.8140 - lr: 0.0010
# Epoch 7/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3290 - accuracy: 1.0000 - val_loss: 0.7959 - val_accuracy: 0.8372 - lr: 0.0010
# Epoch 8/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.2842 - accuracy: 1.0000 - val_loss: 0.7499 - val_accuracy: 0.8140 - lr: 0.0010
# Epoch 9/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2451 - accuracy: 1.0000 - val_loss: 0.7166 - val_accuracy: 0.8372 - lr: 0.0010
# Epoch 10/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2123 - accuracy: 1.0000 - val_loss: 0.6992 - val_accuracy: 0.8372 - lr: 0.0010
# Epoch 11/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.1835 - accuracy: 1.0000 - val_loss: 0.7112 - val_accuracy: 0.8023 - lr: 0.0010
# Epoch 12/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1595 - accuracy: 1.0000 - val_loss: 0.6694 - val_accuracy: 0.8023 - lr: 0.0010
# Epoch 13/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.1393 - accuracy: 1.0000 - val_loss: 0.6529 - val_accuracy: 0.7907 - lr: 0.0010
# Epoch 14/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.1251 - accuracy: 1.0000 - val_loss: 0.6397 - val_accuracy: 0.8023 - lr: 0.0010
# Epoch 15/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1120 - accuracy: 1.0000 - val_loss: 0.6383 - val_accuracy: 0.8023 - lr: 0.0010
# Epoch 16/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1029 - accuracy: 1.0000 - val_loss: 0.6621 - val_accuracy: 0.8023 - lr: 0.0010
# Epoch 17/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0950 - accuracy: 1.0000 - val_loss: 0.6412 - val_accuracy: 0.7791 - lr: 0.0010
# Epoch 18/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0903 - accuracy: 0.9988 - val_loss: 0.6895 - val_accuracy: 0.7674 - lr: 0.0010
# Epoch 19/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1247 - accuracy: 0.9929 - val_loss: 0.8925 - val_accuracy: 0.6860 - lr: 0.0010
# Epoch 20/100
# 27/27 [==============================] - 1s 26ms/step - loss: 0.3216 - accuracy: 0.9716 - val_loss: 1.5547 - val_accuracy: 0.6628 - lr: 0.0010
# Epoch 21/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.7632 - accuracy: 0.9313 - val_loss: 1.7561 - val_accuracy: 0.7326 - lr: 5.0000e-04
# Epoch 22/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.7439 - accuracy: 0.9692 - val_loss: 1.7651 - val_accuracy: 0.6628 - lr: 5.0000e-04
# Epoch 23/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.7168 - accuracy: 0.9917 - val_loss: 1.7303 - val_accuracy: 0.7326 - lr: 5.0000e-04
# Epoch 24/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.6820 - accuracy: 0.9929 - val_loss: 1.6860 - val_accuracy: 0.7093 - lr: 5.0000e-04
# Epoch 25/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.6448 - accuracy: 0.9953 - val_loss: 1.6076 - val_accuracy: 0.7209 - lr: 5.0000e-04
# 3/3 [==============================] - 0s 8ms/step
#
# Validation Metrics for Split 6:
#   Accuracy: 80.23%
#   Sensitivity (Recall): 76.74%
#   Precision: 82.50%
#   Specificity: 83.72%
#   AUC-ROC Score: 83.23%
#   Confusion Matrix:
# [[36  7]
#  [10 33]]
# 2/2 [==============================] - 0s 2ms/step
#
# Test Metrics for Split 6:
#   Accuracy: 75.00%
#   Sensitivity (Recall): 85.71%
#   Precision: 70.59%
#   Specificity: 64.29%
#   AUC-ROC Score: 84.95%
#   Confusion Matrix:
# [[18 10]
#  [ 4 24]]
#
# --- Split 7 ---
# Labels
# Time series data
# atlas rois_cc200: (848, 19900)
# atlas rois_aal: (848, 6670)
# Training set shape: (848, 26570), class balance: ASD=424, TC=424
# Validation set shape: (84, 26570), class balance: ASD=42, TC=42
# Test set shape: (56, 26570), class balance: ASD=28, TC=28
# Epoch 1/100
# 27/27 [==============================] - 2s 36ms/step - loss: 1.0346 - accuracy: 0.6026 - val_loss: 1.0213 - val_accuracy: 0.6786 - lr: 0.0010
# Epoch 2/100
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8006 - accuracy: 0.8597 - val_loss: 1.0131 - val_accuracy: 0.7381 - lr: 0.0010
# Epoch 3/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.5984 - accuracy: 0.9646 - val_loss: 1.0218 - val_accuracy: 0.7262 - lr: 0.0010
# Epoch 4/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.4986 - accuracy: 0.9894 - val_loss: 0.9776 - val_accuracy: 0.7381 - lr: 0.0010
# Epoch 5/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.4186 - accuracy: 0.9976 - val_loss: 0.9739 - val_accuracy: 0.7381 - lr: 0.0010
# Epoch 6/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3596 - accuracy: 0.9988 - val_loss: 0.9100 - val_accuracy: 0.7262 - lr: 0.0010
# Epoch 7/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3095 - accuracy: 0.9988 - val_loss: 0.8584 - val_accuracy: 0.7619 - lr: 0.0010
# Epoch 8/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2618 - accuracy: 1.0000 - val_loss: 0.8146 - val_accuracy: 0.7619 - lr: 0.0010
# Epoch 9/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.2255 - accuracy: 0.9988 - val_loss: 0.8031 - val_accuracy: 0.7381 - lr: 0.0010
# Epoch 10/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1964 - accuracy: 1.0000 - val_loss: 0.8025 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 11/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1693 - accuracy: 1.0000 - val_loss: 0.7664 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 12/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1486 - accuracy: 1.0000 - val_loss: 0.7499 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 13/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1301 - accuracy: 1.0000 - val_loss: 0.7204 - val_accuracy: 0.7619 - lr: 0.0010
# Epoch 14/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1165 - accuracy: 1.0000 - val_loss: 0.6906 - val_accuracy: 0.7738 - lr: 0.0010
# Epoch 15/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1076 - accuracy: 1.0000 - val_loss: 0.7074 - val_accuracy: 0.7619 - lr: 0.0010
# Epoch 16/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.1002 - accuracy: 1.0000 - val_loss: 0.7118 - val_accuracy: 0.7619 - lr: 0.0010
# Epoch 17/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.1003 - accuracy: 0.9988 - val_loss: 0.9399 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 18/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1159 - accuracy: 1.0000 - val_loss: 0.9913 - val_accuracy: 0.7024 - lr: 0.0010
# Epoch 19/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.1440 - accuracy: 1.0000 - val_loss: 1.2143 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 20/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.1927 - accuracy: 0.9965 - val_loss: 1.4053 - val_accuracy: 0.7024 - lr: 5.0000e-04
# Epoch 21/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2147 - accuracy: 0.9965 - val_loss: 1.3960 - val_accuracy: 0.6429 - lr: 5.0000e-04
# Epoch 22/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2220 - accuracy: 0.9988 - val_loss: 1.4649 - val_accuracy: 0.6429 - lr: 5.0000e-04
# Epoch 23/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.2235 - accuracy: 0.9988 - val_loss: 1.3358 - val_accuracy: 0.6905 - lr: 5.0000e-04
# Epoch 24/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2255 - accuracy: 0.9953 - val_loss: 1.2892 - val_accuracy: 0.6786 - lr: 5.0000e-04
# 3/3 [==============================] - 0s 1ms/step
#
# Validation Metrics for Split 7:
#   Accuracy: 77.38%
#   Sensitivity (Recall): 78.57%
#   Precision: 76.74%
#   Specificity: 76.19%
#   AUC-ROC Score: 83.05%
#   Confusion Matrix:
# [[32 10]
#  [ 9 33]]
# 2/2 [==============================] - 0s 0s/step
#
# Test Metrics for Split 7:
#   Accuracy: 82.14%
#   Sensitivity (Recall): 75.00%
#   Precision: 87.50%
#   Specificity: 89.29%
#   AUC-ROC Score: 83.80%
#   Confusion Matrix:
# [[25  3]
#  [ 7 21]]
#
# --- Split 8 ---
# Labels
# Time series data
# atlas rois_cc200: (852, 19900)
# atlas rois_aal: (852, 6670)
# Training set shape: (852, 26570), class balance: ASD=426, TC=426
# Validation set shape: (82, 26570), class balance: ASD=41, TC=41
# Test set shape: (56, 26570), class balance: ASD=28, TC=28
# Epoch 1/100
# 27/27 [==============================] - 2s 37ms/step - loss: 1.0451 - accuracy: 0.5857 - val_loss: 1.0301 - val_accuracy: 0.6707 - lr: 0.0010
# Epoch 2/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.7666 - accuracy: 0.8850 - val_loss: 1.0575 - val_accuracy: 0.6463 - lr: 0.0010
# Epoch 3/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.5812 - accuracy: 0.9695 - val_loss: 1.1043 - val_accuracy: 0.6220 - lr: 0.0010
# Epoch 4/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.4777 - accuracy: 0.9977 - val_loss: 1.1140 - val_accuracy: 0.6707 - lr: 0.0010
# Epoch 5/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.4253 - accuracy: 0.9953 - val_loss: 1.1050 - val_accuracy: 0.6707 - lr: 0.0010
# Epoch 6/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3676 - accuracy: 0.9977 - val_loss: 1.0810 - val_accuracy: 0.6341 - lr: 0.0010
# Epoch 7/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3276 - accuracy: 1.0000 - val_loss: 1.0552 - val_accuracy: 0.6463 - lr: 5.0000e-04
# Epoch 8/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.3034 - accuracy: 1.0000 - val_loss: 1.0403 - val_accuracy: 0.6463 - lr: 5.0000e-04
# Epoch 9/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2793 - accuracy: 0.9988 - val_loss: 1.0257 - val_accuracy: 0.6463 - lr: 5.0000e-04
# Epoch 10/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2563 - accuracy: 0.9988 - val_loss: 1.0054 - val_accuracy: 0.6463 - lr: 5.0000e-04
# Epoch 11/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2338 - accuracy: 1.0000 - val_loss: 0.9820 - val_accuracy: 0.6463 - lr: 5.0000e-04
# Epoch 12/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.2166 - accuracy: 0.9988 - val_loss: 0.9727 - val_accuracy: 0.6585 - lr: 5.0000e-04
# Epoch 13/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.1976 - accuracy: 0.9988 - val_loss: 0.9539 - val_accuracy: 0.6341 - lr: 5.0000e-04
# Epoch 14/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.1805 - accuracy: 1.0000 - val_loss: 0.9302 - val_accuracy: 0.6341 - lr: 5.0000e-04
# Epoch 15/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1656 - accuracy: 1.0000 - val_loss: 0.9226 - val_accuracy: 0.6463 - lr: 5.0000e-04
# Epoch 16/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1519 - accuracy: 1.0000 - val_loss: 0.9243 - val_accuracy: 0.6463 - lr: 5.0000e-04
# Epoch 17/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1399 - accuracy: 1.0000 - val_loss: 0.9086 - val_accuracy: 0.6463 - lr: 5.0000e-04
# Epoch 18/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1286 - accuracy: 1.0000 - val_loss: 0.9008 - val_accuracy: 0.6463 - lr: 5.0000e-04
# Epoch 19/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.1191 - accuracy: 1.0000 - val_loss: 0.8850 - val_accuracy: 0.6829 - lr: 5.0000e-04
# Epoch 20/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.1105 - accuracy: 1.0000 - val_loss: 0.8795 - val_accuracy: 0.6585 - lr: 5.0000e-04
# Epoch 21/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1026 - accuracy: 1.0000 - val_loss: 0.8741 - val_accuracy: 0.6463 - lr: 5.0000e-04
# Epoch 22/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.0958 - accuracy: 1.0000 - val_loss: 0.8903 - val_accuracy: 0.6463 - lr: 5.0000e-04
# Epoch 23/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0919 - accuracy: 0.9988 - val_loss: 0.8821 - val_accuracy: 0.6585 - lr: 5.0000e-04
# Epoch 24/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0963 - accuracy: 0.9988 - val_loss: 0.8772 - val_accuracy: 0.6707 - lr: 5.0000e-04
# Epoch 25/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0867 - accuracy: 1.0000 - val_loss: 0.8872 - val_accuracy: 0.6463 - lr: 5.0000e-04
# Epoch 26/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.1016 - accuracy: 0.9977 - val_loss: 0.8977 - val_accuracy: 0.6463 - lr: 5.0000e-04
# Epoch 27/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0832 - accuracy: 1.0000 - val_loss: 0.9023 - val_accuracy: 0.6463 - lr: 2.5000e-04
# Epoch 28/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0814 - accuracy: 0.9988 - val_loss: 0.8944 - val_accuracy: 0.6220 - lr: 2.5000e-04
# Epoch 29/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0784 - accuracy: 0.9988 - val_loss: 0.8933 - val_accuracy: 0.6220 - lr: 2.5000e-04
# Epoch 30/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0753 - accuracy: 1.0000 - val_loss: 0.8690 - val_accuracy: 0.6463 - lr: 2.5000e-04
# Epoch 31/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0726 - accuracy: 1.0000 - val_loss: 0.8528 - val_accuracy: 0.6341 - lr: 2.5000e-04
# Epoch 32/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0697 - accuracy: 1.0000 - val_loss: 0.8537 - val_accuracy: 0.6341 - lr: 2.5000e-04
# Epoch 33/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0671 - accuracy: 1.0000 - val_loss: 0.8652 - val_accuracy: 0.6341 - lr: 2.5000e-04
# Epoch 34/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0657 - accuracy: 1.0000 - val_loss: 0.8699 - val_accuracy: 0.6341 - lr: 2.5000e-04
# Epoch 35/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0631 - accuracy: 1.0000 - val_loss: 0.8545 - val_accuracy: 0.6341 - lr: 2.5000e-04
# Epoch 36/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0611 - accuracy: 1.0000 - val_loss: 0.8485 - val_accuracy: 0.6220 - lr: 2.5000e-04
# Epoch 37/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0597 - accuracy: 1.0000 - val_loss: 0.8485 - val_accuracy: 0.6463 - lr: 2.5000e-04
# Epoch 38/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0581 - accuracy: 1.0000 - val_loss: 0.8615 - val_accuracy: 0.6463 - lr: 2.5000e-04
# Epoch 39/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0558 - accuracy: 1.0000 - val_loss: 0.8678 - val_accuracy: 0.6463 - lr: 2.5000e-04
# Epoch 40/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0546 - accuracy: 1.0000 - val_loss: 0.8757 - val_accuracy: 0.6463 - lr: 2.5000e-04
# Epoch 41/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0534 - accuracy: 1.0000 - val_loss: 0.8785 - val_accuracy: 0.6463 - lr: 2.5000e-04
# Epoch 42/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0520 - accuracy: 1.0000 - val_loss: 0.8795 - val_accuracy: 0.6220 - lr: 1.2500e-04
# Epoch 43/100
# 27/27 [==============================] - 1s 26ms/step - loss: 0.0512 - accuracy: 1.0000 - val_loss: 0.8797 - val_accuracy: 0.6220 - lr: 1.2500e-04
# Epoch 44/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0506 - accuracy: 1.0000 - val_loss: 0.8849 - val_accuracy: 0.6341 - lr: 1.2500e-04
# Epoch 45/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0498 - accuracy: 1.0000 - val_loss: 0.8890 - val_accuracy: 0.6463 - lr: 1.2500e-04
# Epoch 46/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0487 - accuracy: 1.0000 - val_loss: 0.8932 - val_accuracy: 0.6585 - lr: 1.2500e-04
# Epoch 47/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0480 - accuracy: 1.0000 - val_loss: 0.8956 - val_accuracy: 0.6463 - lr: 6.2500e-05
# 3/3 [==============================] - 0s 8ms/step
#
# Validation Metrics for Split 8:
#   Accuracy: 64.63%
#   Sensitivity (Recall): 58.54%
#   Precision: 66.67%
#   Specificity: 70.73%
#   AUC-ROC Score: 72.69%
#   Confusion Matrix:
# [[29 12]
#  [17 24]]
# 2/2 [==============================] - 0s 5ms/step
#
# Test Metrics for Split 8:
#   Accuracy: 73.21%
#   Sensitivity (Recall): 75.00%
#   Precision: 72.41%
#   Specificity: 71.43%
#   AUC-ROC Score: 83.29%
#   Confusion Matrix:
# [[20  8]
#  [ 7 21]]
#
# --- Split 9 ---
# Labels
# Time series data
# atlas rois_cc200: (852, 19900)
# atlas rois_aal: (852, 6670)
# Training set shape: (852, 26570), class balance: ASD=426, TC=426
# Validation set shape: (80, 26570), class balance: ASD=40, TC=40
# Test set shape: (56, 26570), class balance: ASD=28, TC=28
# Epoch 1/100
# 27/27 [==============================] - 2s 37ms/step - loss: 1.0379 - accuracy: 0.6209 - val_loss: 1.0366 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 2/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.7574 - accuracy: 0.8955 - val_loss: 1.0645 - val_accuracy: 0.7000 - lr: 0.0010
# Epoch 3/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.5675 - accuracy: 0.9824 - val_loss: 1.1013 - val_accuracy: 0.7125 - lr: 0.0010
# Epoch 4/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.4760 - accuracy: 0.9953 - val_loss: 1.0608 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 5/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.4123 - accuracy: 0.9977 - val_loss: 1.0165 - val_accuracy: 0.7000 - lr: 0.0010
# Epoch 6/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3582 - accuracy: 0.9988 - val_loss: 0.9834 - val_accuracy: 0.7125 - lr: 0.0010
# Epoch 7/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.3167 - accuracy: 0.9988 - val_loss: 0.9708 - val_accuracy: 0.7000 - lr: 0.0010
# Epoch 8/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2696 - accuracy: 0.9977 - val_loss: 0.9349 - val_accuracy: 0.7000 - lr: 0.0010
# Epoch 9/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2256 - accuracy: 1.0000 - val_loss: 0.9002 - val_accuracy: 0.7250 - lr: 0.0010
# Epoch 10/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.2017 - accuracy: 0.9988 - val_loss: 0.8938 - val_accuracy: 0.7125 - lr: 0.0010
# Epoch 11/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1789 - accuracy: 0.9988 - val_loss: 0.8871 - val_accuracy: 0.7250 - lr: 0.0010
# Epoch 12/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.1508 - accuracy: 0.9988 - val_loss: 0.8663 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 13/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.1300 - accuracy: 1.0000 - val_loss: 0.8438 - val_accuracy: 0.7375 - lr: 0.0010
# Epoch 14/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1165 - accuracy: 0.9988 - val_loss: 0.7930 - val_accuracy: 0.7375 - lr: 0.0010
# Epoch 15/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.1077 - accuracy: 1.0000 - val_loss: 0.7913 - val_accuracy: 0.7625 - lr: 0.0010
# Epoch 16/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1029 - accuracy: 0.9988 - val_loss: 0.8803 - val_accuracy: 0.7125 - lr: 0.0010
# Epoch 17/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.1307 - accuracy: 0.9977 - val_loss: 0.9946 - val_accuracy: 0.6375 - lr: 0.0010
# Epoch 18/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.2272 - accuracy: 0.9918 - val_loss: 1.5954 - val_accuracy: 0.6125 - lr: 0.0010
# Epoch 19/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.5943 - accuracy: 0.9566 - val_loss: 2.1823 - val_accuracy: 0.7125 - lr: 0.0010
# Epoch 20/100
# 27/27 [==============================] - 1s 27ms/step - loss: 1.1404 - accuracy: 0.9284 - val_loss: 2.8698 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 21/100
# 27/27 [==============================] - 1s 30ms/step - loss: 1.2590 - accuracy: 0.9671 - val_loss: 2.8773 - val_accuracy: 0.5875 - lr: 5.0000e-04
# Epoch 22/100
# 27/27 [==============================] - 1s 27ms/step - loss: 1.2072 - accuracy: 0.9789 - val_loss: 2.6276 - val_accuracy: 0.6250 - lr: 5.0000e-04
# Epoch 23/100
# 27/27 [==============================] - 1s 28ms/step - loss: 1.1040 - accuracy: 0.9930 - val_loss: 2.5586 - val_accuracy: 0.5875 - lr: 5.0000e-04
# Epoch 24/100
# 27/27 [==============================] - 1s 30ms/step - loss: 1.0513 - accuracy: 0.9918 - val_loss: 2.4555 - val_accuracy: 0.6125 - lr: 5.0000e-04
# Epoch 25/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.9551 - accuracy: 0.9965 - val_loss: 2.3888 - val_accuracy: 0.6125 - lr: 5.0000e-04
# 3/3 [==============================] - 0s 517us/step
#
# Validation Metrics for Split 9:
#   Accuracy: 76.25%
#   Sensitivity (Recall): 82.50%
#   Precision: 73.33%
#   Specificity: 70.00%
#   AUC-ROC Score: 77.88%
#   Confusion Matrix:
# [[28 12]
#  [ 7 33]]
# 2/2 [==============================] - 0s 1ms/step
#
# Test Metrics for Split 9:
#   Accuracy: 78.57%
#   Sensitivity (Recall): 82.14%
#   Precision: 76.67%
#   Specificity: 75.00%
#   AUC-ROC Score: 83.93%
#   Confusion Matrix:
# [[21  7]
#  [ 5 23]]
#
# --- Split 10 ---
# Labels
# Time series data
# atlas rois_cc200: (856, 19900)
# atlas rois_aal: (856, 6670)
# Training set shape: (856, 26570), class balance: ASD=428, TC=428
# Validation set shape: (78, 26570), class balance: ASD=39, TC=39
# Test set shape: (56, 26570), class balance: ASD=28, TC=28
# Epoch 1/100
# 27/27 [==============================] - 2s 39ms/step - loss: 1.0554 - accuracy: 0.5771 - val_loss: 1.0548 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 2/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8021 - accuracy: 0.8820 - val_loss: 1.0833 - val_accuracy: 0.6282 - lr: 0.0010
# Epoch 3/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.5872 - accuracy: 0.9790 - val_loss: 1.1044 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 4/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.4921 - accuracy: 0.9965 - val_loss: 1.1084 - val_accuracy: 0.6410 - lr: 0.0010
# Epoch 5/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.4305 - accuracy: 0.9988 - val_loss: 1.0838 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 6/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3711 - accuracy: 1.0000 - val_loss: 1.0501 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 7/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3255 - accuracy: 0.9988 - val_loss: 1.0231 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 8/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2789 - accuracy: 0.9988 - val_loss: 1.0165 - val_accuracy: 0.6282 - lr: 0.0010
# Epoch 9/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2399 - accuracy: 1.0000 - val_loss: 0.9769 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 10/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2184 - accuracy: 0.9988 - val_loss: 0.9357 - val_accuracy: 0.6282 - lr: 0.0010
# Epoch 11/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1809 - accuracy: 1.0000 - val_loss: 0.9736 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 12/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1594 - accuracy: 1.0000 - val_loss: 0.9151 - val_accuracy: 0.6282 - lr: 0.0010
# Epoch 13/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.1417 - accuracy: 1.0000 - val_loss: 0.9100 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 14/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.1261 - accuracy: 1.0000 - val_loss: 0.9343 - val_accuracy: 0.6410 - lr: 0.0010
# Epoch 15/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.1272 - accuracy: 0.9988 - val_loss: 0.9942 - val_accuracy: 0.5897 - lr: 0.0010
# Epoch 16/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1255 - accuracy: 0.9988 - val_loss: 0.9334 - val_accuracy: 0.6923 - lr: 0.0010
# Epoch 17/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.1492 - accuracy: 0.9977 - val_loss: 1.1073 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 18/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1383 - accuracy: 0.9988 - val_loss: 1.0136 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 19/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.1303 - accuracy: 0.9988 - val_loss: 1.0070 - val_accuracy: 0.6538 - lr: 5.0000e-04
# Epoch 20/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1272 - accuracy: 0.9988 - val_loss: 0.8913 - val_accuracy: 0.6667 - lr: 5.0000e-04
# Epoch 21/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1290 - accuracy: 1.0000 - val_loss: 0.9474 - val_accuracy: 0.6538 - lr: 5.0000e-04
# Epoch 22/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1270 - accuracy: 1.0000 - val_loss: 0.9734 - val_accuracy: 0.6667 - lr: 5.0000e-04
# Epoch 23/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1194 - accuracy: 0.9988 - val_loss: 0.9521 - val_accuracy: 0.6795 - lr: 5.0000e-04
# Epoch 24/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1147 - accuracy: 1.0000 - val_loss: 1.0484 - val_accuracy: 0.6667 - lr: 5.0000e-04
# Epoch 25/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.1078 - accuracy: 1.0000 - val_loss: 1.0378 - val_accuracy: 0.6923 - lr: 5.0000e-04
# Epoch 26/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1017 - accuracy: 1.0000 - val_loss: 1.0036 - val_accuracy: 0.6795 - lr: 2.5000e-04
# Epoch 27/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0980 - accuracy: 1.0000 - val_loss: 0.9875 - val_accuracy: 0.6795 - lr: 2.5000e-04
# Epoch 28/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0926 - accuracy: 1.0000 - val_loss: 0.9941 - val_accuracy: 0.6795 - lr: 2.5000e-04
# Epoch 29/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0880 - accuracy: 1.0000 - val_loss: 0.9925 - val_accuracy: 0.6795 - lr: 2.5000e-04
# Epoch 30/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0853 - accuracy: 1.0000 - val_loss: 0.9885 - val_accuracy: 0.6667 - lr: 2.5000e-04
# 3/3 [==============================] - 0s 8ms/step
#
# Validation Metrics for Split 10:
#   Accuracy: 66.67%
#   Sensitivity (Recall): 69.23%
#   Precision: 65.85%
#   Specificity: 64.10%
#   AUC-ROC Score: 75.48%
#   Confusion Matrix:
# [[25 14]
#  [12 27]]
# 2/2 [==============================] - 0s 16ms/step
#
# Test Metrics for Split 10:
#   Accuracy: 67.86%
#   Sensitivity (Recall): 82.14%
#   Precision: 63.89%
#   Specificity: 53.57%
#   AUC-ROC Score: 78.95%
#   Confusion Matrix:
# [[15 13]
#  [ 5 23]]
#
# --- Mean Validation Metrics Across All Splits ---
# Accuracy: 72.82%
# Sensitivity: 72.26%
# Precision: 73.23%
# Specificity: 73.38%
# Auc: 78.73%
#
# --- Mean Test Metrics Across All Splits ---
# Accuracy: 74.64%
# Sensitivity: 78.93%
# Precision: 73.21%
# Specificity: 70.36%
# Auc: 82.61%

# %%
X_data, X_test = np.array([None]), np.array([None])
y_data = []

# Aggregate labels from all sites except the test site
for site in sites:
    if site == test_site:  # Skip the test site
        continue

    # Add training labels for the current split
    y_data.extend(atlas_labels[site])

y_test = atlas_labels[test_site]

for atlas in range(len(atlases)):
    # Initialize lists for training data
    X_train_time_series_atlas = []

    # Aggregate data from all sites except the test site
    for site in sites:
        if site == test_site:  # Skip the test site
            continue

        # Add training data for the current site
        X_train_time_series_atlas.extend(
            atlas_time_series[atlas][site]
        )

    # Estimate tangent space representation for training data
    connectivity_m = estimate_tangent_space(X_train_time_series_atlas)
    # Transform data into feature vectors
    X_train_atlas = connectivity_m.transform(X_train_time_series_atlas)
    X_test_atlas = connectivity_m.transform(atlas_time_series[atlas][test_site])

    if X_data.any() == None:
        X_data = X_train_atlas
    else:
        X_data = np.concatenate((X_data, X_train_atlas),axis=1)

    if X_test.any() == None:
        X_test = X_test_atlas
    else:
        X_test = np.concatenate((X_test, X_test_atlas),axis=1)

# %% [markdown]
# Handles the data preparation, model training, and evaluation on training, validation, and test datasets.
#
# 1. **Splitting the Data**:
#    - The training data (`X_data`, `y_data`) is split into training (`X_train`, `y_train`) and validation (`X_val`, `y_val`) sets using `train_test_split` with stratification to preserve class balance.
#    - The test set remains separate as `X_test` and `y_test`.
#
# 2. **Data Conversion**:
#    - Training, validation, and test datasets (`X_train`, `X_val`, `X_test`, `y_train`, `y_val`, `y_test`) are converted to numpy arrays for compatibility with the model.
#
# 3. **Dataset Statistics**:
#    - Prints the shapes of the training, validation, and test sets along with the class distribution for `ASD` (positive class) and `TC` (negative class).
#
# 4. **Model Training**:
#    - A deep neural network (DNN) is constructed using the `build_model` function, with the input shape derived from `X_train`.
#    - The model is trained on the training set (`X_train`, `y_train`) and evaluated on the validation set (`X_val`, `y_val`) using:
#      - Batch size: 32
#      - Epochs: 100
#      - Callbacks: `callbacks_list` for monitoring and early stopping.
#
# 5. **Evaluation**:
#    - Predictions and metrics (accuracy, sensitivity, precision, specificity, AUC) are calculated for the following sets:
#      - **Training Set**:
#        - Predictions: `train_pred_prob`, thresholded at 0.5 for binary classification.
#        - Metrics calculated using `calculate_metrics` and printed using `print_metrics`.
#      - **Validation Set**:
#        - Predictions: `val_pred_prob`, thresholded at 0.5 for binary classification.
#        - Metrics calculated and printed as above.
#      - **Test Set**:
#        - Predictions: `test_pred_prob`, thresholded at 0.5 for binary classification.
#        - Metrics calculated and printed as above.

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_data, y_data, stratify=y_data, test_size=0.2)

# Convert labels to numpy arrays
X_train, X_val, X_test = map(np.array, [X_train, X_val, X_test])
y_train, y_val, y_test = map(np.array, [y_train, y_val, y_test])

# Print dataset statistics
print(f"Training set shape: {X_train.shape}, class balance: ASD={np.sum(y_train == 1)}, TC={np.sum(y_train == 0)}")
print(f"Validation set shape: {X_val.shape}, class balance: ASD={np.sum(y_val == 1)}, TC={np.sum(y_val == 0)}")
print(f"Test set shape: {X_test.shape}, class balance: ASD={np.sum(y_test == 1)}, TC={np.sum(y_test == 0)}")

# Build and train the model
dnn = build_model(X_train.shape[1])
history = dnn.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=32, epochs=100, callbacks=callbacks_list)

# Evaluate on training set
train_pred_prob = dnn.predict(X_train).ravel()
train_pred = (train_pred_prob > 0.5).astype(int)
acc, sens, prec, spec, auc, cm = calculate_metrics(y_train, train_pred, train_pred_prob)
print_metrics(1, "training", acc, sens, prec, spec, auc, cm)

# Evaluate on validation set
val_pred_prob = dnn.predict(X_val).ravel()
val_pred = (val_pred_prob > 0.5).astype(int)
acc, sens, prec, spec, auc, cm = calculate_metrics(y_val, val_pred, val_pred_prob)
print_metrics(1, "validation", acc, sens, prec, spec, auc, cm)

# Evaluate on test set
test_pred_prob = dnn.predict(X_test).ravel()
test_pred = (test_pred_prob > 0.5).astype(int)
acc, sens, prec, spec, auc, cm = calculate_metrics(y_test, test_pred, test_pred_prob)
print_metrics(1, "test", acc, sens, prec, spec, auc, cm)
# Out:
# Training set shape: (835, 26570), class balance: ASD=401, TC=434
# Validation set shape: (209, 26570), class balance: ASD=100, TC=109
# Test set shape: (56, 26570), class balance: ASD=28, TC=28
# Epoch 1/100
# 27/27 [==============================] - 2s 42ms/step - loss: 1.0428 - accuracy: 0.5940 - val_loss: 1.0342 - val_accuracy: 0.7129 - lr: 0.0010
# Epoch 2/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.8000 - accuracy: 0.8671 - val_loss: 1.0358 - val_accuracy: 0.7416 - lr: 0.0010
# Epoch 3/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.6106 - accuracy: 0.9737 - val_loss: 1.0547 - val_accuracy: 0.7321 - lr: 0.0010
# Epoch 4/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.5090 - accuracy: 0.9892 - val_loss: 1.0549 - val_accuracy: 0.7225 - lr: 0.0010
# Epoch 5/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.4442 - accuracy: 1.0000 - val_loss: 1.0212 - val_accuracy: 0.7464 - lr: 0.0010
# Epoch 6/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3957 - accuracy: 0.9976 - val_loss: 0.9786 - val_accuracy: 0.7273 - lr: 0.0010
# Epoch 7/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.3414 - accuracy: 0.9976 - val_loss: 0.9436 - val_accuracy: 0.7273 - lr: 0.0010
# Epoch 8/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.2977 - accuracy: 1.0000 - val_loss: 0.9265 - val_accuracy: 0.7321 - lr: 0.0010
# Epoch 9/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2579 - accuracy: 1.0000 - val_loss: 0.9002 - val_accuracy: 0.7273 - lr: 0.0010
# Epoch 10/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.2253 - accuracy: 0.9988 - val_loss: 0.8658 - val_accuracy: 0.7273 - lr: 0.0010
# Epoch 11/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.1973 - accuracy: 0.9988 - val_loss: 0.8315 - val_accuracy: 0.7273 - lr: 0.0010
# Epoch 12/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.1909 - accuracy: 0.9964 - val_loss: 0.8423 - val_accuracy: 0.7368 - lr: 0.0010
# Epoch 13/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2022 - accuracy: 0.9976 - val_loss: 0.8797 - val_accuracy: 0.7177 - lr: 0.0010
# Epoch 14/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.1810 - accuracy: 0.9976 - val_loss: 0.8430 - val_accuracy: 0.7129 - lr: 0.0010
# Epoch 15/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1574 - accuracy: 1.0000 - val_loss: 0.8554 - val_accuracy: 0.7129 - lr: 0.0010
# Epoch 16/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1429 - accuracy: 1.0000 - val_loss: 0.8052 - val_accuracy: 0.7368 - lr: 0.0010
# Epoch 17/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.1306 - accuracy: 1.0000 - val_loss: 0.8113 - val_accuracy: 0.7321 - lr: 0.0010
# Epoch 18/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1351 - accuracy: 0.9976 - val_loss: 0.9037 - val_accuracy: 0.7321 - lr: 0.0010
# Epoch 19/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1708 - accuracy: 0.9976 - val_loss: 0.9754 - val_accuracy: 0.6986 - lr: 0.0010
# Epoch 20/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.2571 - accuracy: 0.9880 - val_loss: 1.3319 - val_accuracy: 0.6842 - lr: 0.0010
# Epoch 21/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.5190 - accuracy: 0.9617 - val_loss: 1.9701 - val_accuracy: 0.6172 - lr: 0.0010
# Epoch 22/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.8133 - accuracy: 0.9677 - val_loss: 2.2164 - val_accuracy: 0.6459 - lr: 5.0000e-04
# Epoch 23/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.8530 - accuracy: 0.9832 - val_loss: 2.1357 - val_accuracy: 0.6364 - lr: 5.0000e-04
# Epoch 24/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.7904 - accuracy: 0.9892 - val_loss: 2.0757 - val_accuracy: 0.6411 - lr: 5.0000e-04
# Epoch 25/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.7388 - accuracy: 0.9940 - val_loss: 2.0253 - val_accuracy: 0.6268 - lr: 5.0000e-04
# Epoch 26/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6797 - accuracy: 0.9988 - val_loss: 1.9347 - val_accuracy: 0.6364 - lr: 5.0000e-04
# 27/27 [==============================] - 0s 4ms/step
#
# Training Metrics for Split 2:
#   Accuracy: 100.00%
#   Sensitivity (Recall): 100.00%
#   Precision: 100.00%
#   Specificity: 100.00%
#   AUC-ROC Score: 100.00%
#   Confusion Matrix:
# [[434   0]
#  [  0 401]]
# 7/7 [==============================] - 0s 7ms/step
#
# Validation Metrics for Split 2:
#   Accuracy: 73.68%
#   Sensitivity (Recall): 72.00%
#   Precision: 72.73%
#   Specificity: 75.23%
#   AUC-ROC Score: 78.06%
#   Confusion Matrix:
# [[82 27]
#  [28 72]]
# 2/2 [==============================] - 0s 8ms/step
#
# Test Metrics for Split 2:
#   Accuracy: 76.79%
#   Sensitivity (Recall): 78.57%
#   Precision: 75.86%
#   Specificity: 75.00%
#   AUC-ROC Score: 80.23%
#   Confusion Matrix:
# [[21  7]
#  [ 6 22]]
